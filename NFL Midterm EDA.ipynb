# %%
import requests
import json
from pprint import pprint
import pandas as pd

# %%
# The df that we are going to pull is nfl score data from espn

# %%
# The question we are looking to answer is if we can predict the total points 
# that will be scored during this weekend's superbowl game

# %%
# Step 1
# We began by collecting raw NFL game data from ESPN’s public API 
# without filtering variables, so we could first understand what 
# information was available

# %%
response = requests.get("https://site.api.espn.com/apis/site/v2/sports/football/nfl/scoreboard")
print(response.status_code)

raw_data = response.json()
# Out:
# 200

# %%
pprint(response.json())
# Out:
# {'events': [{'competitions': [{'attendance': 0,
#                                'broadcast': 'NBC/Peacock',
#                                'broadcasts': [{'market': 'national',
#                                                'names': ['NBC', 'Peacock']}],
#                                'competitors': [{'homeAway': 'home',
#                                                 'id': '17',
#                                                 'leaders': [{'abbreviation': 'PYDS',
#                                                              'displayName': 'Passing '
#                                                                             'Leader',
#                                                              'leaders': [{'athlete': {'active': True,
#                                                                                       'displayName': 'Drake '
#                                                                                                      'Maye',
#                                                                                       'fullName': 'Drake '
#                                                                                                   'Maye',
#                                                                                       'headshot': 'https://a.espncdn.com/i/headshots/nfl/players/full/4431452.png',
#                                                                                       'id': '4431452',
#                                                                                       'jersey': '10',
#                                                                                       'links': [{'href': 'https://www.espn.com/nfl/player/_/id/4431452/drake-maye',
#                                                                                                  'rel': ['playercard',
#                                                                                                          'desktop',
#                                                                                                          'athlete']}],
#                                                                                       'position': {'abbreviation': 'QB'},
#                                                                                       'shortName': 'D. '
#                                                                                                    'Maye',
#                                                                                       'team': {'id': '17'}},
#                                                                           'displayValue': '354/492, '
#                                                                                           '4394 '
#                                                                                           'YDS, '
#                                                                                           '31 '
#                                                                                           'TD, '
#                                                                                           '8 '
#                                                                                           'INT',
#                                                                           'team': {'id': '17'},
#                                                                           'value': 4394.0}],
#                                                              'name': 'passingLeader',
#                                                              'shortDisplayName': 'PASS'},
#                                                             {'abbreviation': 'RYDS',
#                                                              'displayName': 'Rushing '
#                                                                             'Leader',
#                                                              'leaders': [{'athlete': {'active': True,
#                                                                                       'displayName': 'TreVeyon '
#                                                                                                      'Henderson',
#                                                                                       'fullName': 'TreVeyon '
#                                                                                                   'Henderson',
#                                                                                       'headshot': 'https://a.espncdn.com/i/headshots/nfl/players/full/4432710.png',
#                                                                                       'id': '4432710',
#                                                                                       'jersey': '32',
#                                                                                       'links': [{'href': 'https://www.espn.com/nfl/player/_/id/4432710/treveyon-henderson',
#                                                                                                  'rel': ['playercard',
#                                                                                                          'desktop',
#                                                                                                          'athlete']}],
#                                                                                       'position': {'abbreviation': 'RB'},
#                                                                                       'shortName': 'T. '
#                                                                                                    'Henderson',
#                                                                                       'team': {'id': '17'}},
#                                                                           'displayValue': '180 '
#                                                                                           'CAR, '
#                                                                                           '911 '
#                                                                                           'YDS, '
#                                                                                           '9 '
#                                                                                           'TD',
#                                                                           'team': {'id': '17'},
#                                                                           'value': 911.0}],
#                                                              'name': 'rushingLeader',
#                                                              'shortDisplayName': 'RUSH'},
#                                                             {'abbreviation': 'RECYDS',
#                                                              'displayName': 'Receiving '
#                                                                             'Leader',
#                                                              'leaders': [{'athlete': {'active': True,
#                                                                                       'displayName': 'Stefon '
#                                                                                                      'Diggs',
#                                                                                       'fullName': 'Stefon '
#                                                                                                   'Diggs',
#                                                                                       'headshot': 'https://a.espncdn.com/i/headshots/nfl/players/full/2976212.png',
#                                                                                       'id': '2976212',
#                                                                                       'jersey': '8',
#                                                                                       'links': [{'href': 'https://www.espn.com/nfl/player/_/id/2976212/stefon-diggs',
#                                                                                                  'rel': ['playercard',
#                                                                                                          'desktop',
#                                                                                                          'athlete']}],
#                                                                                       'position': {'abbreviation': 'WR'},
#                                                                                       'shortName': 'S. '
#                                                                                                    'Diggs',
#                                                                                       'team': {'id': '17'}},
#                                                                           'displayValue': '85 '
#                                                                                           'REC, '
#                                                                                           '1013 '
#                                                                                           'YDS, '
#                                                                                           '4 '
#                                                                                           'TD',
#                                                                           'team': {'id': '17'},
#                                                                           'value': 1013.0}],
#                                                              'name': 'receivingLeader',
#                                                              'shortDisplayName': 'REC'}],
#                                                 'order': 0,
#                                                 'records': [{'abbreviation': 'Any',
#                                                              'name': 'overall',
#                                                              'summary': '14-3',
#                                                              'type': 'total'},
#                                                             {'name': 'Home',
#                                                              'summary': '6-3',
#                                                              'type': 'home'},
#                                                             {'name': 'Road',
#                                                              'summary': '8-0',
#                                                              'type': 'road'}],
#                                                 'score': '0',
#                                                 'statistics': [],
#                                                 'team': {'abbreviation': 'NE',
#                                                          'alternateColor': 'c60c30',
#                                                          'color': '002a5c',
#                                                          'displayName': 'New '
#                                                                         'England '
#                                                                         'Patriots',
#                                                          'id': '17',
#                                                          'isActive': True,
#                                                          'links': [{'href': 'https://www.espn.com/nfl/team/_/name/ne/new-england-patriots',
#                                                                     'isExternal': False,
#                                                                     'isPremium': False,
#                                                                     'rel': ['clubhouse',
#                                                                             'desktop',
#                                                                             'team'],
#                                                                     'text': 'Clubhouse'},
#                                                                    {'href': 'https://www.espn.com/nfl/team/roster/_/name/ne/new-england-patriots',
#                                                                     'isExternal': False,
#                                                                     'isPremium': False,
#                                                                     'rel': ['roster',
#                                                                             'desktop',
#                                                                             'team'],
#                                                                     'text': 'Roster'},
#                                                                    {'href': 'https://www.espn.com/nfl/team/stats/_/name/ne/new-england-patriots',
#                                                                     'isExternal': False,
#                                                                     'isPremium': False,
#                                                                     'rel': ['stats',
#                                                                             'desktop',
#                                                                             'team'],
#                                                                     'text': 'Statistics'},
#                                                                    {'href': 'https://www.espn.com/nfl/team/schedule/_/name/ne',
#                                                                     'isExternal': False,
#                                                                     'isPremium': False,
#                                                                     'rel': ['schedule',
#                                                                             'desktop',
#                                                                             'team'],
#                                                                     'text': 'Schedule'}],
#                                                          'location': 'New '
#                                                                      'England',
#                                                          'logo': 'https://a.espncdn.com/i/teamlogos/nfl/500/scoreboard/ne.png',
#                                                          'name': 'Patriots',
#                                                          'shortDisplayName': 'Patriots',
#                                                          'uid': 's:20~l:28~t:17',
#                                                          'venue': {'id': '3738'}},
#                                                 'type': 'team',
#                                                 'uid': 's:20~l:28~t:17'},
#                                                {'homeAway': 'away',
#                                                 'id': '26',
#                                                 'leaders': [{'abbreviation': 'PYDS',
#                                                              'displayName': 'Passing '
#                                                                             'Leader',
#                                                              'leaders': [{'athlete': {'active': True,
#                                                                                       'displayName': 'Sam '
#                                                                                                      'Darnold',
#                                                                                       'fullName': 'Sam '
#                                                                                                   'Darnold',
#                                                                                       'headshot': 'https://a.espncdn.com/i/headshots/nfl/players/full/3912547.png',
#                                                                                       'id': '3912547',
#                                                                                       'jersey': '14',
#                                                                                       'links': [{'href': 'https://www.espn.com/nfl/player/_/id/3912547/sam-darnold',
#                                                                                                  'rel': ['playercard',
#                                                                                                          'desktop',
#                                                                                                          'athlete']}],
#                                                                                       'position': {'abbreviation': 'QB'},
#                                                                                       'shortName': 'S. '
#                                                                                                    'Darnold',
#                                                                                       'team': {'id': '26'}},
#                                                                           'displayValue': '323/477, '
#                                                                                           '4048 '
#                                                                                           'YDS, '
#                                                                                           '25 '
#                                                                                           'TD, '
#                                                                                           '14 '
#                                                                                           'INT',
#                                                                           'team': {'id': '26'},
#                                                                           'value': 4048.0}],
#                                                              'name': 'passingLeader',
#                                                              'shortDisplayName': 'PASS'},
#                                                             {'abbreviation': 'RYDS',
#                                                              'displayName': 'Rushing '
#                                                                             'Leader',
#                                                              'leaders': [{'athlete': {'active': True,
#                                                                                       'displayName': 'Kenneth '
#                                                                                                      'Walker '
#                                                                                                      'III',
#                                                                                       'fullName': 'Kenneth '
#                                                                                                   'Walker '
#                                                                                                   'III',
#                                                                                       'headshot': 'https://a.espncdn.com/i/headshots/nfl/players/full/4567048.png',
#                                                                                       'id': '4567048',
#                                                                                       'jersey': '9',
#                                                                                       'links': [{'href': 'https://www.espn.com/nfl/player/_/id/4567048/kenneth-walker-iii',
#                                                                                                  'rel': ['playercard',
#                                                                                                          'desktop',
#                                                                                                          'athlete']}],
#                                                                                       'position': {'abbreviation': 'RB'},
#                                                                                       'shortName': 'K. '
#                                                                                                    'Walker '
#                                                                                                    'III',
#                                                                                       'team': {'id': '26'}},
#                                                                           'displayValue': '221 '
#                                                                                           'CAR, '
#                                                                                           '1027 '
#                                                                                           'YDS, '
#                                                                                           '5 '
#                                                                                           'TD',
#                                                                           'team': {'id': '26'},
#                                                                           'value': 1027.0}],
#                                                              'name': 'rushingLeader',
#                                                              'shortDisplayName': 'RUSH'},
#                                                             {'abbreviation': 'RECYDS',
#                                                              'displayName': 'Receiving '
#                                                                             'Leader',
#                                                              'leaders': [{'athlete': {'active': True,
#                                                                                       'displayName': 'Jaxon '
#                                                                                                      'Smith-Njigba',
#                                                                                       'fullName': 'Jaxon '
#                                                                                                   'Smith-Njigba',
#                                                                                       'headshot': 'https://a.espncdn.com/i/headshots/nfl/players/full/4430878.png',
#                                                                                       'id': '4430878',
#                                                                                       'jersey': '11',
#                                                                                       'links': [{'href': 'https://www.espn.com/nfl/player/_/id/4430878/jaxon-smith-njigba',
#                                                                                                  'rel': ['playercard',
#                                                                                                          'desktop',
#                                                                                                          'athlete']}],
#                                                                                       'position': {'abbreviation': 'WR'},
#                                                                                       'shortName': 'J. '
#                                                                                                    'Smith-Njigba',
#                                                                                       'team': {'id': '26'}},
#                                                                           'displayValue': '119 '
#                                                                                           'REC, '
#                                                                                           '1793 '
#                                                                                           'YDS, '
#                                                                                           '10 '
#                                                                                           'TD',
#                                                                           'team': {'id': '26'},
#                                                                           'value': 1793.0}],
#                                                              'name': 'receivingLeader',
#                                                              'shortDisplayName': 'REC'}],
#                                                 'order': 1,
#                                                 'records': [{'abbreviation': 'Any',
#                                                              'name': 'overall',
#                                                              'summary': '14-3',
#                                                              'type': 'total'},
#                                                             {'name': 'Home',
#                                                              'summary': '6-2',
#                                                              'type': 'home'},
#                                                             {'name': 'Road',
#                                                              'summary': '8-1',
#                                                              'type': 'road'}],
#                                                 'score': '0',
#                                                 'statistics': [],
#                                                 'team': {'abbreviation': 'SEA',
#                                                          'alternateColor': '69be28',
#                                                          'color': '002a5c',
#                                                          'displayName': 'Seattle '
#                                                                         'Seahawks',
#                                                          'id': '26',
#                                                          'isActive': True,
#                                                          'links': [{'href': 'https://www.espn.com/nfl/team/_/name/sea/seattle-seahawks',
#                                                                     'isExternal': False,
#                                                                     'isPremium': False,
#                                                                     'rel': ['clubhouse',
#                                                                             'desktop',
#                                                                             'team'],
#                                                                     'text': 'Clubhouse'},
#                                                                    {'href': 'https://www.espn.com/nfl/team/roster/_/name/sea/seattle-seahawks',
#                                                                     'isExternal': False,
#                                                                     'isPremium': False,
#                                                                     'rel': ['roster',
#                                                                             'desktop',
#                                                                             'team'],
#                                                                     'text': 'Roster'},
#                                                                    {'href': 'https://www.espn.com/nfl/team/stats/_/name/sea/seattle-seahawks',
#                                                                     'isExternal': False,
#                                                                     'isPremium': False,
#                                                                     'rel': ['stats',
#                                                                             'desktop',
#                                                                             'team'],
#                                                                     'text': 'Statistics'},
#                                                                    {'href': 'https://www.espn.com/nfl/team/schedule/_/name/sea',
#                                                                     'isExternal': False,
#                                                                     'isPremium': False,
#                                                                     'rel': ['schedule',
#                                                                             'desktop',
#                                                                             'team'],
#                                                                     'text': 'Schedule'}],
#                                                          'location': 'Seattle',
#                                                          'logo': 'https://a.espncdn.com/i/teamlogos/nfl/500/scoreboard/sea.png',
#                                                          'name': 'Seahawks',
#                                                          'shortDisplayName': 'Seahawks',
#                                                          'uid': 's:20~l:28~t:26',
#                                                          'venue': {'id': '3673'}},
#                                                 'type': 'team',
#                                                 'uid': 's:20~l:28~t:26'}],
#                                'conferenceCompetition': False,
#                                'date': '2026-02-08T23:30Z',
#                                'format': {'regulation': {'periods': 4}},
#                                'geoBroadcasts': [{'lang': 'en',
#                                                   'market': {'id': '1',
#                                                              'type': 'National'},
#                                                   'media': {'shortName': 'NBC'},
#                                                   'region': 'us',
#                                                   'type': {'id': '1',
#                                                            'shortName': 'TV'}},
#                                                  {'lang': 'en',
#                                                   'market': {'id': '1',
#                                                              'type': 'National'},
#                                                   'media': {'shortName': 'Peacock'},
#                                                   'region': 'us',
#                                                   'type': {'id': '4',
#                                                            'shortName': 'Streaming'}}],
#                                'highlights': [],
#                                'id': '401772988',
#                                'leaders': [{'abbreviation': 'PYDS',
#                                             'displayName': 'Passing Leader',
#                                             'leaders': [{'athlete': {'active': True,
#                                                                      'displayName': 'Drake '
#                                                                                     'Maye',
#                                                                      'fullName': 'Drake '
#                                                                                  'Maye',
#                                                                      'headshot': 'https://a.espncdn.com/i/headshots/nfl/players/full/4431452.png',
#                                                                      'id': '4431452',
#                                                                      'jersey': '10',
#                                                                      'links': [{'href': 'https://www.espn.com/nfl/player/_/id/4431452/drake-maye',
#                                                                                 'rel': ['playercard',
#                                                                                         'desktop',
#                                                                                         'athlete']}],
#                                                                      'position': {'abbreviation': 'QB'},
#                                                                      'shortName': 'D. '
#                                                                                   'Maye',
#                                                                      'team': {'id': '17'}},
#                                                          'displayValue': '4394 '
#                                                                          'YDS, '
#                                                                          '31 '
#                                                                          'TD, '
#                                                                          '8 '
#                                                                          'INT',
#                                                          'team': {'id': '17'},
#                                                          'value': 4394.0}],
#                                             'name': 'passingYards',
#                                             'shortDisplayName': 'PASS'},
#                                            {'abbreviation': 'RYDS',
#                                             'displayName': 'Rushing Leader',
#                                             'leaders': [{'athlete': {'active': True,
#                                                                      'displayName': 'Kenneth '
#                                                                                     'Walker '
#                                                                                     'III',
#                                                                      'fullName': 'Kenneth '
#                                                                                  'Walker '
#                                                                                  'III',
#                                                                      'headshot': 'https://a.espncdn.com/i/headshots/nfl/players/full/4567048.png',
#                                                                      'id': '4567048',
#                                                                      'jersey': '9',
#                                                                      'links': [{'href': 'https://www.espn.com/nfl/player/_/id/4567048/kenneth-walker-iii',
#                                                                                 'rel': ['playercard',
#                                                                                         'desktop',
#                                                                                         'athlete']}],
#                                                                      'position': {'abbreviation': 'RB'},
#                                                                      'shortName': 'K. '
#                                                                                   'Walker '
#                                                                                   'III',
#                                                                      'team': {'id': '26'}},
#                                                          'displayValue': '221 '
#                                                                          'CAR, '
#                                                                          '1027 '
#                                                                          'YDS, '
#                                                                          '5 TD',
#                                                          'team': {'id': '26'},
#                                                          'value': 1027.0}],
#                                             'name': 'rushingYards',
#                                             'shortDisplayName': 'RUSH'},
#                                            {'abbreviation': 'RECYDS',
#                                             'displayName': 'Receiving Leader',
#                                             'leaders': [{'athlete': {'active': True,
#                                                                      'displayName': 'Jaxon '
#                                                                                     'Smith-Njigba',
#                                                                      'fullName': 'Jaxon '
#                                                                                  'Smith-Njigba',
#                                                                      'headshot': 'https://a.espncdn.com/i/headshots/nfl/players/full/4430878.png',
#                                                                      'id': '4430878',
#                                                                      'jersey': '11',
#                                                                      'links': [{'href': 'https://www.espn.com/nfl/player/_/id/4430878/jaxon-smith-njigba',
#                                                                                 'rel': ['playercard',
#                                                                                         'desktop',
#                                                                                         'athlete']}],
#                                                                      'position': {'abbreviation': 'WR'},
#                                                                      'shortName': 'J. '
#                                                                                   'Smith-Njigba',
#                                                                      'team': {'id': '26'}},
#                                                          'displayValue': '119 '
#                                                                          'REC, '
#                                                                          '1793 '
#                                                                          'YDS, '
#                                                                          '10 '
#                                                                          'TD',
#                                                          'team': {'id': '26'},
#                                                          'value': 1793.0}],
#                                             'name': 'receivingYards',
#                                             'shortDisplayName': 'REC'}],
#                                'neutralSite': True,
#                                'notes': [{'headline': 'Super Bowl LX',
#                                           'type': 'event'}],
#                                'odds': [{'awayTeamOdds': {'favorite': True,
#                                                           'favoriteAtOpen': True,
#                                                           'team': {'abbreviation': 'SEA',
#                                                                    'displayName': 'Seattle '
#                                                                                   'Seahawks',
#                                                                    'id': '26',
#                                                                    'logo': 'https://a.espncdn.com/i/teamlogos/nfl/500/scoreboard/sea.png',
#                                                                    'name': 'Seahawks',
#                                                                    'uid': 's:20~l:28~t:26'},
#                                                           'underdog': False},
#                                          'details': 'SEA -4.5',
#                                          'footer': {'disclaimer': 'Odds by '
#                                                                   'DraftKings\n'
#                                                                   'GAMBLING '
#                                                                   'PROBLEM? '
#                                                                   'CALL '
#                                                                   '1-800-GAMBLER, '
#                                                                   '(800) '
#                                                                   '327-5050 or '
#                                                                   'visit '
#                                                                   'gamblinghelplinema.org '
#                                                                   '(MA). Call '
#                                                                   '877-8-HOPENY/text '
#                                                                   'HOPENY '
#                                                                   '(467369) '
#                                                                   '(NY).\n'
#                                                                   'Please '
#                                                                   'Gamble '
#                                                                   'Responsibly. '
#                                                                   '888-789-7777/visit '
#                                                                   'ccpg.org '
#                                                                   '(CT), or '
#                                                                   'visit '
#                                                                   'www.mdgamblinghelp.org '
#                                                                   '(MD).\n'
#                                                                   '21+ and '
#                                                                   'present in '
#                                                                   'most '
#                                                                   'states. '
#                                                                   '(18+ '
#                                                                   'DC/KY/NH/WY). '
#                                                                   'Void in '
#                                                                   'ONT/OR/NH. '
#                                                                   'Eligibility '
#                                                                   'restrictions '
#                                                                   'apply. On '
#                                                                   'behalf of '
#                                                                   'Boot Hill '
#                                                                   'Casino & '
#                                                                   'Resort '
#                                                                   '(KS). '
#                                                                   'Terms: '
#                                                                   'sportsbook.draftkings.com/promos.'},
#                                          'header': {'logo': {'dark': 'https://a.espncdn.com/i/espnbet/dark/espn-bet-square-off.svg',
#                                                              'exclusivesLogoDark': 'https://a.espncdn.com/i/espnbet/espn-bet-square-mint.svg',
#                                                              'exclusivesLogoLight': 'https://a.espncdn.com/i/espnbet/espn-bet-square-mint.svg',
#                                                              'light': 'https://a.espncdn.com/i/espnbet/espn-bet-square-off.svg'},
#                                                     'text': 'Game Odds'},
#                                          'homeTeamOdds': {'favorite': False,
#                                                           'favoriteAtOpen': False,
#                                                           'team': {'abbreviation': 'NE',
#                                                                    'displayName': 'New '
#                                                                                   'England '
#                                                                                   'Patriots',
#                                                                    'id': '17',
#                                                                    'logo': 'https://a.espncdn.com/i/teamlogos/nfl/500/scoreboard/ne.png',
#                                                                    'name': 'Patriots',
#                                                                    'uid': 's:20~l:28~t:17'},
#                                                           'underdog': True},
#                                          'link': {'href': 'https://sportsbook.draftkings.com/gateway?s=__s__&wpcid=__wpcid__&wpsrc=413&wpcn=ESPN&wpscn=Widget&wpcrn=BetSlipDeepLink&wpscid=__wpscid__&wpcrid=xx&preurl=https%3A%2F%2Fsportsbook.draftkings.com%2Fevent%2F33488086',
#                                                   'isExternal': True,
#                                                   'isPremium': False,
#                                                   'language': 'en-US',
#                                                   'rel': ['game',
#                                                           'desktop',
#                                                           'bets'],
#                                                   'shortText': 'Game',
#                                                   'text': 'See More Odds',
#                                                   'tracking': {'campaign': 'betting-integrations',
#                                                                'tags': {'betSide': 'none',
#                                                                         'betType': 'straight',
#                                                                         'gameId': 401772988,
#                                                                         'league': 'nfl',
#                                                                         'sport': 'football'}}},
#                                          'moneyline': {'away': {'close': {'link': {'href': 'https://sportsbook.draftkings.com/gateway?s=__s__&wpcid=__wpcid__&wpsrc=413&wpcn=ESPN&wpscn=Widget&wpcrn=BetSlipDeepLink&wpscid=__wpscid__&wpcrid=xx&preurl=https%3A%2F%2Fsportsbook.draftkings.com%2Fevent%2F33488086%3Foutcomes%3D0ML83048305_3',
#                                                                                    'isExternal': True,
#                                                                                    'isPremium': False,
#                                                                                    'language': 'en-US',
#                                                                                    'rel': ['away',
#                                                                                            'desktop',
#                                                                                            'bets',
#                                                                                            'draft-kings'],
#                                                                                    'shortText': 'Away '
#                                                                                                 'Bet',
#                                                                                    'text': 'Away '
#                                                                                            'Bet',
#                                                                                    'tracking': {'campaign': 'betting-integrations',
#                                                                                                 'tags': {'betSide': 'away',
#                                                                                                          'betType': 'straight',
# ...
#              'date': '2026-02-08T23:30Z',
#              'id': '401772988',
#              'links': [{'href': 'https://www.espn.com/nfl/game/_/gameId/401772988/seahawks-patriots',
#                         'isExternal': False,
#                         'isPremium': False,
#                         'language': 'en-US',
#                         'rel': ['summary', 'desktop', 'event'],
#                         'shortText': 'Gamecast',
#                         'text': 'Gamecast'}],
#              'name': 'Seattle Seahawks at New England Patriots',
#              'season': {'slug': 'post-season', 'type': 3, 'year': 2025},
#              'shortName': 'SEA VS NE',
#              'status': {'clock': 0.0,
#                         'displayClock': '0:00',
#                         'period': 0,
#                         'type': {'completed': False,
#                                  'description': 'Scheduled',
#                                  'detail': 'Sun, February 8th at 6:30 PM EST',
#                                  'id': '1',
#                                  'name': 'STATUS_SCHEDULED',
#                                  'shortDetail': '2/8 - 6:30 PM EST',
#                                  'state': 'pre'}},
#              'uid': 's:20~l:28~e:401772988',
#              'weather': {'conditionId': '3',
#                          'displayValue': 'Partly sunny',
#                          'highTemperature': 65,
#                          'link': {'href': 'http://www.accuweather.com/en/us/levis-stadium-ca/95050/hourly-weather-forecast/53539_poi?day=1&hbhhour=15&lang=en-us',
#                                   'isExternal': True,
#                                   'isPremium': False,
#                                   'language': 'en-US',
#                                   'rel': ['95054'],
#                                   'shortText': 'Weather',
#                                   'text': 'Weather'},
#                          'temperature': 65},
#              'week': {'number': 5}}],
#  'leagues': [{'abbreviation': 'NFL',
#               'calendar': [{'endDate': '2025-09-04T06:59Z',
#                             'entries': [{'alternateLabel': 'HOF',
#                                          'detail': 'Jul 31-Aug 6',
#                                          'endDate': '2025-08-07T06:59Z',
#                                          'label': 'Hall of Fame Weekend',
#                                          'startDate': '2025-07-31T07:00Z',
#                                          'value': '1'},
#                                         {'alternateLabel': 'Pre Wk 1',
#                                          'detail': 'Aug 7-13',
#                                          'endDate': '2025-08-14T06:59Z',
#                                          'label': 'Preseason Week 1',
#                                          'startDate': '2025-08-07T07:00Z',
#                                          'value': '2'},
#                                         {'alternateLabel': 'Pre Wk 2',
#                                          'detail': 'Aug 14-20',
#                                          'endDate': '2025-08-21T06:59Z',
#                                          'label': 'Preseason Week 2',
#                                          'startDate': '2025-08-14T07:00Z',
#                                          'value': '3'},
#                                         {'alternateLabel': 'Pre Wk 3',
#                                          'detail': 'Aug 21-Sep 3',
#                                          'endDate': '2025-09-04T06:59Z',
#                                          'label': 'Preseason Week 3',
#                                          'startDate': '2025-08-21T07:00Z',
#                                          'value': '4'}],
#                             'label': 'Preseason',
#                             'startDate': '2025-07-31T07:00Z',
#                             'value': '1'},
#                            {'endDate': '2026-01-07T07:59Z',
#                             'entries': [{'alternateLabel': 'Week 1',
#                                          'detail': 'Sep 4-9',
#                                          'endDate': '2025-09-10T06:59Z',
#                                          'label': 'Week 1',
#                                          'startDate': '2025-09-04T07:00Z',
#                                          'value': '1'},
#                                         {'alternateLabel': 'Week 2',
#                                          'detail': 'Sep 10-16',
#                                          'endDate': '2025-09-17T06:59Z',
#                                          'label': 'Week 2',
#                                          'startDate': '2025-09-10T07:00Z',
#                                          'value': '2'},
#                                         {'alternateLabel': 'Week 3',
#                                          'detail': 'Sep 17-23',
#                                          'endDate': '2025-09-24T06:59Z',
#                                          'label': 'Week 3',
#                                          'startDate': '2025-09-17T07:00Z',
#                                          'value': '3'},
#                                         {'alternateLabel': 'Week 4',
#                                          'detail': 'Sep 24-30',
#                                          'endDate': '2025-10-01T06:59Z',
#                                          'label': 'Week 4',
#                                          'startDate': '2025-09-24T07:00Z',
#                                          'value': '4'},
#                                         {'alternateLabel': 'Week 5',
#                                          'detail': 'Oct 1-7',
#                                          'endDate': '2025-10-08T06:59Z',
#                                          'label': 'Week 5',
#                                          'startDate': '2025-10-01T07:00Z',
#                                          'value': '5'},
#                                         {'alternateLabel': 'Week 6',
#                                          'detail': 'Oct 8-14',
#                                          'endDate': '2025-10-15T06:59Z',
#                                          'label': 'Week 6',
#                                          'startDate': '2025-10-08T07:00Z',
#                                          'value': '6'},
#                                         {'alternateLabel': 'Week 7',
#                                          'detail': 'Oct 15-21',
#                                          'endDate': '2025-10-22T06:59Z',
#                                          'label': 'Week 7',
#                                          'startDate': '2025-10-15T07:00Z',
#                                          'value': '7'},
#                                         {'alternateLabel': 'Week 8',
#                                          'detail': 'Oct 22-28',
#                                          'endDate': '2025-10-29T06:59Z',
#                                          'label': 'Week 8',
#                                          'startDate': '2025-10-22T07:00Z',
#                                          'value': '8'},
#                                         {'alternateLabel': 'Week 9',
#                                          'detail': 'Oct 29-Nov 4',
#                                          'endDate': '2025-11-05T07:59Z',
#                                          'label': 'Week 9',
#                                          'startDate': '2025-10-29T07:00Z',
#                                          'value': '9'},
#                                         {'alternateLabel': 'Week 10',
#                                          'detail': 'Nov 5-11',
#                                          'endDate': '2025-11-12T07:59Z',
#                                          'label': 'Week 10',
#                                          'startDate': '2025-11-05T08:00Z',
#                                          'value': '10'},
#                                         {'alternateLabel': 'Week 11',
#                                          'detail': 'Nov 12-18',
#                                          'endDate': '2025-11-19T07:59Z',
#                                          'label': 'Week 11',
#                                          'startDate': '2025-11-12T08:00Z',
#                                          'value': '11'},
#                                         {'alternateLabel': 'Week 12',
#                                          'detail': 'Nov 19-25',
#                                          'endDate': '2025-11-26T07:59Z',
#                                          'label': 'Week 12',
#                                          'startDate': '2025-11-19T08:00Z',
#                                          'value': '12'},
#                                         {'alternateLabel': 'Week 13',
#                                          'detail': 'Nov 26-Dec 2',
#                                          'endDate': '2025-12-03T07:59Z',
#                                          'label': 'Week 13',
#                                          'startDate': '2025-11-26T08:00Z',
#                                          'value': '13'},
#                                         {'alternateLabel': 'Week 14',
#                                          'detail': 'Dec 3-9',
#                                          'endDate': '2025-12-10T07:59Z',
#                                          'label': 'Week 14',
#                                          'startDate': '2025-12-03T08:00Z',
#                                          'value': '14'},
#                                         {'alternateLabel': 'Week 15',
#                                          'detail': 'Dec 10-16',
#                                          'endDate': '2025-12-17T07:59Z',
#                                          'label': 'Week 15',
#                                          'startDate': '2025-12-10T08:00Z',
#                                          'value': '15'},
#                                         {'alternateLabel': 'Week 16',
#                                          'detail': 'Dec 17-23',
#                                          'endDate': '2025-12-24T07:59Z',
#                                          'label': 'Week 16',
#                                          'startDate': '2025-12-17T08:00Z',
#                                          'value': '16'},
#                                         {'alternateLabel': 'Week 17',
#                                          'detail': 'Dec 24-30',
#                                          'endDate': '2025-12-31T07:59Z',
#                                          'label': 'Week 17',
#                                          'startDate': '2025-12-24T08:00Z',
#                                          'value': '17'},
#                                         {'alternateLabel': 'Week 18',
#                                          'detail': 'Dec 31-Jan 6',
#                                          'endDate': '2026-01-07T07:59Z',
#                                          'label': 'Week 18',
#                                          'startDate': '2025-12-31T08:00Z',
#                                          'value': '18'}],
#                             'label': 'Regular Season',
#                             'startDate': '2025-09-04T07:00Z',
#                             'value': '2'},
#                            {'endDate': '2026-02-12T07:59Z',
#                             'entries': [{'alternateLabel': 'Wild Card',
#                                          'detail': 'Jan 7-13',
#                                          'endDate': '2026-01-14T07:59Z',
#                                          'label': 'Wild Card',
#                                          'startDate': '2026-01-07T08:00Z',
#                                          'value': '1'},
#                                         {'alternateLabel': 'Div Rd',
#                                          'detail': 'Jan 14-20',
#                                          'endDate': '2026-01-21T07:59Z',
#                                          'label': 'Divisional Round',
#                                          'startDate': '2026-01-14T08:00Z',
#                                          'value': '2'},
#                                         {'alternateLabel': 'Conf Champ',
#                                          'detail': 'Jan 21-27',
#                                          'endDate': '2026-01-28T07:59Z',
#                                          'label': 'Conference Championship',
#                                          'startDate': '2026-01-21T08:00Z',
#                                          'value': '3'},
#                                         {'alternateLabel': 'Pro Bowl',
#                                          'detail': 'Jan 28-Feb 3',
#                                          'endDate': '2026-02-04T07:59Z',
#                                          'label': 'Pro Bowl',
#                                          'startDate': '2026-01-28T08:00Z',
#                                          'value': '4'},
#                                         {'alternateLabel': 'Super Bowl',
#                                          'detail': 'Feb 4-11',
#                                          'endDate': '2026-02-12T07:59Z',
#                                          'label': 'Super Bowl',
#                                          'startDate': '2026-02-04T08:00Z',
#                                          'value': '5'}],
#                             'label': 'Postseason',
#                             'startDate': '2026-01-07T08:00Z',
#                             'value': '3'},
#                            {'endDate': '2026-08-06T06:59Z',
#                             'entries': [{'alternateLabel': 'Week 1',
#                                          'detail': 'Feb 12-Jul 31',
#                                          'endDate': '2026-08-01T06:59Z',
#                                          'label': 'Week 1',
#                                          'startDate': '2026-02-12T08:00Z',
#                                          'value': '1'}],
#                             'label': 'Off Season',
#                             'startDate': '2026-02-12T08:00Z',
#                             'value': '4'}],
#               'calendarEndDate': '2026-02-12T07:59Z',
#               'calendarIsWhitelist': True,
#               'calendarStartDate': '2025-07-31T07:00Z',
#               'calendarType': 'list',
#               'id': '28',
#               'logos': [{'alt': '',
#                          'height': 500,
#                          'href': 'https://a.espncdn.com/i/teamlogos/leagues/500/nfl.png',
#                          'lastUpdated': '2018-06-05T12:07Z',
#                          'rel': ['full', 'default'],
#                          'width': 500},
#                         {'alt': '',
#                          'height': 500,
#                          'href': 'https://a.espncdn.com/i/teamlogos/leagues/500-dark/nfl.png',
#                          'lastUpdated': '2024-07-22T16:53Z',
#                          'rel': ['full', 'dark'],
#                          'width': 500}],
#               'name': 'National Football League',
#               'season': {'displayName': '2025',
#                          'endDate': '2026-02-12T07:59Z',
#                          'startDate': '2025-07-31T07:00Z',
#                          'type': {'abbreviation': 'post',
#                                   'id': '3',
#                                   'name': 'Postseason',
#                                   'type': 3},
#                          'year': 2025},
#               'slug': 'nfl',
#               'uid': 's:20~l:28'}],
#  'provider': {'displayName': 'Draft Kings',
#               'id': '100',
#               'logos': [{'href': 'https://a.espncdn.com/i/betting/Draftkings_Light.svg',
#                          'rel': ['light']},
#                         {'href': 'https://a.espncdn.com/i/betting/Draftkings_Dark.svg',
#                          'rel': ['dark']}],
#               'name': 'Draft Kings',
#               'priority': 1},
#  'season': {'type': 3, 'year': 2025},
#  'week': {'number': 5}}

# %%
def extract_game_fields(event):
    comps = event.get("competitions", [])
    if not comps:
        return None

    comp = comps[0]

    competitors = comp.get("competitors", [])
    if not competitors:
        return None

    home = next((t for t in competitors if t.get("homeAway") == "home"), None)
    away = next((t for t in competitors if t.get("homeAway") == "away"), None)
    if home is None or away is None:
        return None

    venue = comp.get("venue", {}) or {}
    address = venue.get("address", {}) or {}     # <-- NEW
    weather = event.get("weather", {}) or {}

    def safe_int(x):
        try:
            return int(x)
        except (TypeError, ValueError):
            return 0

    home_score = safe_int(home.get("score"))
    away_score = safe_int(away.get("score"))

    season = event.get("season", {}) or {}
    week = event.get("week", {}) or {}
    status = event.get("status", {}).get("type", {}) or {}

    return {
        "game_id": event.get("id"),
        "season": season.get("year"),
        "season_type": season.get("type"),
        "week": week.get("number"),
        "date": event.get("date"),

        "home_team": home.get("team", {}).get("displayName"),
        "away_team": away.get("team", {}).get("displayName"),

        "home_score": home_score,
        "away_score": away_score,
        "total_points": home_score + away_score,

        "venue_id": venue.get("id"),
        "venue_name": venue.get("fullName"),
        "venue_city": address.get("city"),
        "venue_state": address.get("state"),
        "venue_country": address.get("country"),

        "indoor": venue.get("indoor"),
        "temperature": weather.get("temperature"),
        "weather": weather.get("displayValue"),
        "status": status.get("name"),
    }

# %%
# We isolated the most relevant columns from our API and pulled a random game to
# assess the return

# %%
import random

events = raw_data["events"]
sample_events = random.sample(events, min(5, len(events)))

sample_rows = [extract_game_fields(e) for e in sample_events]

sample_raw_nfl_game_data_df = pd.DataFrame(sample_rows)
sample_raw_nfl_game_data_df
# Out:
#      game_id  season  season_type  week               date  \
# 0  401772988    2025            3     5  2026-02-08T23:30Z
#
#               home_team         away_team  home_score  away_score  \
# 0  New England Patriots  Seattle Seahawks           0           0
#
#    total_points venue_id      venue_name   venue_city venue_state  \
# 0             0     4738  Levi's Stadium  Santa Clara          CA
#
#   venue_country  indoor  temperature       weather            status
# 0           USA   False           65  Partly sunny  STATUS_SCHEDULED

# %%
# The return gave us relevent information, but the random game was for a future game
# hence the total score being 0, so we will have to isolate a date range to identify
# which games we want to look at

# %%
# Our goal is to predict the total score for the superbowl, so we only want games
# that are similar to the superbowl. Based on our research, the NFL significantly
# changed scoring rules in 1994, but we will clean that data later.

# %%
sample_raw_nfl_game_data_df["date"].dtype
# Out:
# dtype('O')

# %%
# We noticed that date is a string, so we are converting it into a real datetime object
# so we can filter by year

# %%
sample_raw_nfl_game_data_df["date"] = pd.to_datetime(
    sample_raw_nfl_game_data_df["date"],
    errors="coerce"
)

# %%
sample_raw_nfl_game_data_df["date"].dtype
# Out:
# datetime64[ns, UTC]

# %%
# Now we will pull data from 1994 until now to start creating a df

# %%
BASE_URL = "https://site.api.espn.com/apis/site/v2/sports/football/nfl/scoreboard"

def get_scoreboard(start_date, end_date):
    dates_param = start_date.strftime("%Y%m%d") + "-" + end_date.strftime("%Y%m%d")
    response = requests.get(BASE_URL, params={"dates": dates_param})
    response.raise_for_status()
    return response.json()

# %%
print(response.status_code)
# Out:
# 200

# %%
import datetime as dt

start = dt.date(1994, 1, 1)
end = dt.date.today()

all_events = []

current = start
while current <= end:
    window_end = min(current + dt.timedelta(days=6), end)

    data = get_scoreboard(current, window_end)
    all_events.extend(data.get("events", []))

    current = window_end + dt.timedelta(days=1)

# %%
print("DONE. Total events:", len(all_events))
# Out:
# DONE. Total events: 10111

# %%
def extract_game_fields(event):
    comps = event.get("competitions", [])
    if not comps:
        return None

    comp = comps[0]

    competitors = comp.get("competitors", [])
    if not competitors:
        return None

    home = next((t for t in competitors if t.get("homeAway") == "home"), None)
    away = next((t for t in competitors if t.get("homeAway") == "away"), None)
    if home is None or away is None:
        return None

    venue = comp.get("venue", {}) or {}
    address = venue.get("address", {}) or {}   # <-- added
    weather = event.get("weather", {}) or {}

    def safe_int(x):
        try:
            return int(x)
        except (TypeError, ValueError):
            return 0

    home_score = safe_int(home.get("score"))
    away_score = safe_int(away.get("score"))

    season = event.get("season", {}) or {}
    week = event.get("week", {}) or {}
    status = event.get("status", {}).get("type", {}) or {}

    return {
        "game_id": event.get("id"),
        "season": season.get("year"),
        "season_type": season.get("type"),
        "week": week.get("number"),
        "date": event.get("date"),

        "home_team": home.get("team", {}).get("displayName"),
        "away_team": away.get("team", {}).get("displayName"),

        "home_score": home_score,
        "away_score": away_score,
        "total_points": home_score + away_score,

        "venue_id": venue.get("id"),
        "venue_name": venue.get("fullName"),
        "venue_city": address.get("city"),
        "venue_state": address.get("state"),
        "venue_country": address.get("country"),

        "indoor": venue.get("indoor"),
        "temperature": weather.get("temperature"),
        "weather": weather.get("displayValue"),

        "status": status.get("name"),
    }

# %%
rows = [extract_game_fields(e) for e in all_events]
rows = [r for r in rows if r is not None]  # drop weird/incomplete events

# %%
raw_nfl_game_data_df = pd.DataFrame(rows)
raw_nfl_game_data_df.head()
# Out:
#      game_id  season  season_type  week               date  \
# 0  140102001    1993            2   NaN  1994-01-02T05:00Z
# 1  140102008    1993            2   NaN  1994-01-02T05:00Z
# 2  140102010    1993            2   NaN  1994-01-02T05:00Z
# 3  140102011    1993            2   NaN  1994-01-02T05:00Z
# 4  140102012    1993            2   NaN  1994-01-02T05:00Z
#
#             home_team          away_team  home_score  away_score  \
# 0     Atlanta Falcons  Phoenix Cardinals          10          27
# 1       Detroit Lions  Green Bay Packers          30          20
# 2      Houston Oilers      New York Jets          24           0
# 3  Indianapolis Colts      Buffalo Bills          10          30
# 4  Kansas City Chiefs   Seattle Seahawks          34          24
#
#    total_points venue_id venue_name venue_city venue_state venue_country  \
# 0            37     None       None       None        None          None
# 1            50     None       None       None        None          None
# 2            24     None       None       None        None          None
# 3            40     None       None       None        None          None
# 4            58     None       None       None        None          None
#
#   indoor  temperature weather        status
# 0   None          NaN    None  STATUS_FINAL
# 1   None          NaN    None  STATUS_FINAL
# 2   None          NaN    None  STATUS_FINAL
# 3   None          NaN    None  STATUS_FINAL
# 4   None          NaN    None  STATUS_FINAL

# %%
raw_nfl_game_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10110 entries, 0 to 10109
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   game_id        10110 non-null  object
#  1   season         10110 non-null  int64
#  2   season_type    10110 non-null  int64
#  3   week           8816 non-null   float64
#  4   date           10110 non-null  object
#  5   home_team      10110 non-null  object
#  6   away_team      10110 non-null  object
#  7   home_score     10110 non-null  int64
#  8   away_score     10110 non-null  int64
#  9   total_points   10110 non-null  int64
#  10  venue_id       6891 non-null   object
#  11  venue_name     6891 non-null   object
#  12  venue_city     6890 non-null   object
#  13  venue_state    6835 non-null   object
#  14  venue_country  6890 non-null   object
#  15  indoor         6891 non-null   object
#  16  temperature    1 non-null      float64
#  17  weather        1 non-null      object
#  18  status         10110 non-null  object
# dtypes: float64(2), int64(5), object(12)
# memory usage: 1.5+ MB

# %%
# We pulled data from the 1994 season until now and are assessing the kind of data
# available. Initially it looks like we have most of the games (10,109), but not all
# since it should be closer to 16,000 games (32 teams x ~17 games per season x 31 yrs)
# We also see that some data is strings, weather data is missing, and some location 
# data is missing. Now we will assess if theres a trend in the games with missing data

# %%
raw_nfl_game_data_df["season_type"].value_counts(dropna=False)
# Out:
# season_type
# 2    8168
# 1    1543
# 3     399
# Name: count, dtype: int64

# %%
raw_nfl_game_data_df["status"].value_counts(dropna=False)
# Out:
# status
# STATUS_FINAL        10106
# STATUS_POSTPONED        3
# STATUS_SCHEDULED        1
# Name: count, dtype: int64

# %%
raw_nfl_game_data_df["indoor"].value_counts(dropna=False)
# Out:
# indoor
# False    5040
# None     3219
# True     1851
# Name: count, dtype: int64

# %%
# Season type shows preseason (1), regular season (2), and post season (3)
# The vast majority of games are final, which is good
# There is a lot of missing data on if the game is indoor or not
# We will now assess if the data becomes more reliable over time

# %%
raw_nfl_game_data_df.groupby("season")["indoor"].apply(lambda x: x.notna().mean())
# Out:
# season
# 1986    0.000000
# 1988    0.000000
# 1992    0.000000
# 1993    0.041667
# 1994    0.076596
# 1995    0.071713
# 1996    0.071713
# 1997    0.108000
# 1998    0.103586
# 1999    0.131274
# 2000    0.114198
# 2001    0.114551
# 2002    0.116766
# 2003    0.110778
# 2004    0.116766
# 2005    0.113772
# 2006    0.882883
# 2007    0.882883
# 2008    0.996997
# 2009    0.996997
# 2010    1.000000
# 2011    1.000000
# 2012    1.000000
# 2013    0.996997
# 2014    1.000000
# 2015    1.000000
# 2016    1.000000
# 2017    1.000000
# 2018    1.000000
# 2019    1.000000
# 2020    1.000000
# 2021    1.000000
# 2022    1.000000
# 2023    1.000000
# 2024    1.000000
# 2025    1.000000
# Name: indoor, dtype: float64

# %%
# Based on this information indoor game information is vary unreliable until 2006
# when it is populated 88% of the time and after 2010 it is reliable

# %%
# Our analysis revealed that venue-level indoor/outdoor data is largely unavailable
# prior to the mid-2000s, with coverage increasing sharply around 2006 and reaching 
# full completeness by 2010. This indicates that indoor status is a modern feature in 
# the ESPN dataset and must be handled carefully when analyzing earlier seasons

# %%
raw_nfl_game_data_df.groupby("season")["total_points"].mean()
# Out:
# season
# 1986    24.000000
# 1988    28.000000
# 1992    51.000000
# 1993    42.750000
# 1994    37.642553
# 1995    40.701195
# 1996    38.597610
# 1997    38.340000
# 1998    39.788845
# 1999    39.019305
# 2000    38.108025
# 2001    37.551084
# 2002    42.464072
# 2003    40.925150
# 2004    41.637725
# 2005    40.491018
# 2006    40.219219
# 2007    42.186186
# 2008    42.381381
# 2009    42.276276
# 2010    43.708709
# 2011    43.256024
# 2012    44.759760
# 2013    45.762763
# 2014    44.140719
# 2015    44.135135
# 2016    44.021084
# 2017    42.183183
# 2018    45.174174
# 2019    44.099099
# 2020    49.490706
# 2021    44.688623
# 2022    43.437126
# 2023    43.438806
# 2024    44.674627
# 2025    45.325373
# Name: total_points, dtype: float64

# %%
# Based on this information, I will exlude games before the 2006 season because the
# indoor venue data is more complete and total point variation looks reasonable
# We will create a new df with only the data we want

# %%
analysis_df = raw_nfl_game_data_df[
    raw_nfl_game_data_df["season"] >= 2006
].copy()

# %%
analysis_df["season"].min(), analysis_df["season"].max()
# Out:
# (np.int64(2006), np.int64(2025))

# %%
# We confirmed that only data from seasons 2006 to 2025 are present
# Now we remember from earlier that not all games are final/complete, so we will also
# exclude games that are not final

# %%
analysis_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6603 entries, 3507 to 10109
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   game_id        6603 non-null   object
#  1   season         6603 non-null   int64
#  2   season_type    6603 non-null   int64
#  3   week           6601 non-null   float64
#  4   date           6603 non-null   object
#  5   home_team      6603 non-null   object
#  6   away_team      6603 non-null   object
#  7   home_score     6603 non-null   int64
#  8   away_score     6603 non-null   int64
#  9   total_points   6603 non-null   int64
#  10  venue_id       6522 non-null   object
#  11  venue_name     6522 non-null   object
#  12  venue_city     6521 non-null   object
#  13  venue_state    6466 non-null   object
#  14  venue_country  6521 non-null   object
#  15  indoor         6522 non-null   object
#  16  temperature    1 non-null      float64
#  17  weather        1 non-null      object
#  18  status         6603 non-null   object
# dtypes: float64(2), int64(5), object(12)
# memory usage: 1.0+ MB

# %%
analysis_df = analysis_df[
    analysis_df["status"] == "STATUS_FINAL"
]

# %%
analysis_df["status"].value_counts()
# Out:
# status
# STATUS_FINAL    6600
# Name: count, dtype: int64

# %%
# Now we will also exclude preseason games because they are normally played by backups
# therefore not similar enough to superbowl to help predict the total points scored

# %%
analysis_df = analysis_df[
    analysis_df["season_type"].isin([2, 3])
]

# %%
analysis_df["season_type"].value_counts()
# Out:
# season_type
# 2    5199
# 3     250
# Name: count, dtype: int64

# %%
analysis_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5449 entries, 3572 to 10108
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   game_id        5449 non-null   object
#  1   season         5449 non-null   int64
#  2   season_type    5449 non-null   int64
#  3   week           5449 non-null   float64
#  4   date           5449 non-null   object
#  5   home_team      5449 non-null   object
#  6   away_team      5449 non-null   object
#  7   home_score     5449 non-null   int64
#  8   away_score     5449 non-null   int64
#  9   total_points   5449 non-null   int64
#  10  venue_id       5386 non-null   object
#  11  venue_name     5386 non-null   object
#  12  venue_city     5386 non-null   object
#  13  venue_state    5331 non-null   object
#  14  venue_country  5386 non-null   object
#  15  indoor         5386 non-null   object
#  16  temperature    0 non-null      float64
#  17  weather        0 non-null      object
#  18  status         5449 non-null   object
# dtypes: float64(2), int64(5), object(12)
# memory usage: 851.4+ KB

# %%
# Next we see that some information is a string instead of data types that
# we can do analysis. So we will start converting the data types.

# %%
# starting with date, we will convert that data into datetime

# %%
analysis_df["date"] = pd.to_datetime(
    analysis_df["date"],
    errors="coerce",
    utc=True
)

# %%
analysis_df["date"].dtype
# Out:
# datetime64[ns, UTC]

# %%
analysis_df["date"].isna().sum()
# Out:
# np.int64(0)

# %%
analysis_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5449 entries, 3572 to 10108
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   game_id        5449 non-null   object
#  1   season         5449 non-null   int64
#  2   season_type    5449 non-null   int64
#  3   week           5449 non-null   float64
#  4   date           5449 non-null   datetime64[ns, UTC]
#  5   home_team      5449 non-null   object
#  6   away_team      5449 non-null   object
#  7   home_score     5449 non-null   int64
#  8   away_score     5449 non-null   int64
#  9   total_points   5449 non-null   int64
#  10  venue_id       5386 non-null   object
#  11  venue_name     5386 non-null   object
#  12  venue_city     5386 non-null   object
#  13  venue_state    5331 non-null   object
#  14  venue_country  5386 non-null   object
#  15  indoor         5386 non-null   object
#  16  temperature    0 non-null      float64
#  17  weather        0 non-null      object
#  18  status         5449 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(2), int64(5), object(11)
# memory usage: 851.4+ KB

# %%
analysis_df["indoor"].value_counts(dropna=False)
# Out:
# indoor
# False    3899
# True     1487
# None       63
# Name: count, dtype: int64

# %%
# We know that there are 63 games with missing information on whether it was indoor or
# outdoor. From previous analysis, we can know the missing information is from earlier
# seasons, but we will double check which seasons have that info missing

# %%
analysis_df.groupby("season")["indoor"].apply(lambda x: x.isna().mean())
# Out:
# season
# 2006    0.111940
# 2007    0.115672
# 2008    0.003731
# 2009    0.000000
# 2010    0.000000
# 2011    0.000000
# 2012    0.000000
# 2013    0.003731
# 2014    0.000000
# 2015    0.000000
# 2016    0.000000
# 2017    0.000000
# 2018    0.000000
# 2019    0.000000
# 2020    0.000000
# 2021    0.000000
# 2022    0.000000
# 2023    0.000000
# 2024    0.000000
# 2025    0.000000
# Name: indoor, dtype: float64

# %%
analysis_df.loc[
    analysis_df["indoor"].isna()].sample(10)
# Out:
#         game_id  season  season_type  week                      date  \
# 3719  261119015    2006            2  11.0 2006-11-19 18:00:00+00:00
# 3663  261022015    2006            2   7.0 2006-10-22 17:00:00+00:00
# 3837  270121011    2006            3   3.0 2007-01-21 23:30:00+00:00
# 6168  340126035    2013            3   4.0 2014-01-27 00:30:00+00:00
# 3705  261112015    2006            2  10.0 2006-11-12 18:00:00+00:00
# 3760  261203015    2006            2  13.0 2006-12-03 21:05:00+00:00
# 3592  260917011    2006            2   2.0 2006-09-17 17:00:00+00:00
# 4143  271223016    2007            2  16.0 2007-12-24 01:15:00+00:00
# 4150  271230015    2007            2  17.0 2007-12-30 18:00:00+00:00
# 3669  261022013    2006            2   7.0 2006-10-22 20:15:00+00:00
#
#                home_team             away_team  home_score  away_score  \
# 3719      Miami Dolphins     Minnesota Vikings          24          20
# 3663      Miami Dolphins     Green Bay Packers          24          34
# 3837  Indianapolis Colts  New England Patriots          38          34
# 6168           Team Rice          Team Sanders          21          22
# 3705      Miami Dolphins    Kansas City Chiefs          13          10
# 3760      Miami Dolphins  Jacksonville Jaguars          10          24
# 3592  Indianapolis Colts        Houston Texans          43          24
# 4143   Minnesota Vikings   Washington Redskins          21          32
# 4150      Miami Dolphins    Cincinnati Bengals          25          38
# 3669     Oakland Raiders     Arizona Cardinals          22           9
#
#       total_points venue_id venue_name venue_city venue_state venue_country  \
# 3719            44     None       None       None        None          None
# 3663            58     None       None       None        None          None
# 3837            72     None       None       None        None          None
# 6168            43     None       None       None        None          None
# 3705            23     None       None       None        None          None
# 3760            34     None       None       None        None          None
# 3592            67     None       None       None        None          None
# 4143            53     None       None       None        None          None
# 4150            63     None       None       None        None          None
# 3669            31     None       None       None        None          None
#
#      indoor  temperature weather        status
# 3719   None          NaN    None  STATUS_FINAL
# 3663   None          NaN    None  STATUS_FINAL
# 3837   None          NaN    None  STATUS_FINAL
# 6168   None          NaN    None  STATUS_FINAL
# 3705   None          NaN    None  STATUS_FINAL
# 3760   None          NaN    None  STATUS_FINAL
# 3592   None          NaN    None  STATUS_FINAL
# 4143   None          NaN    None  STATUS_FINAL
# 4150   None          NaN    None  STATUS_FINAL
# 3669   None          NaN    None  STATUS_FINAL

# %%
# It looks like about 10% of indoor data is missing from 2006 and 2007 and only .3%
# is missing from 2008 and 2009. Since we are going to assess total score data
# in relation to weather conditions, it is critical that we know if the games were
# indoor or outdoor. We will now look at the types of games with missing venue data

# %%
analysis_df.groupby("home_team")["indoor"].apply(lambda x: x.notna().mean()).sort_values()
# Out:
# home_team
# Team Rice                0.000000
# Afc                      0.800000
# Oakland Raiders          0.866071
# Indianapolis Colts       0.895349
# Miami Dolphins           0.914634
# Minnesota Vikings        0.916168
# Team Carter              1.000000
# NFC All-Stars            1.000000
# New England Patriots     1.000000
# New Orleans Saints       1.000000
# New York Giants          1.000000
# New York Jets            1.000000
# Washington               1.000000
# Nfc                      1.000000
# Tennessee Titans         1.000000
# Philadelphia Eagles      1.000000
# Pittsburgh Steelers      1.000000
# NFC                      1.000000
# San Francisco 49ers      1.000000
# Seattle Seahawks         1.000000
# St. Louis Rams           1.000000
# Tampa Bay Buccaneers     1.000000
# Team Irvin               1.000000
# San Diego Chargers       1.000000
# AFC                      1.000000
# Los Angeles Rams         1.000000
# AFC All-Stars            1.000000
# Arizona Cardinals        1.000000
# Atlanta Falcons          1.000000
# Baltimore Ravens         1.000000
# Buffalo Bills            1.000000
# Carolina Panthers        1.000000
# Chicago Bears            1.000000
# Cincinnati Bengals       1.000000
# Washington Commanders    1.000000
# Cleveland Browns         1.000000
# Denver Broncos           1.000000
# Detroit Lions            1.000000
# Green Bay Packers        1.000000
# Houston Texans           1.000000
# Jacksonville Jaguars     1.000000
# Kansas City Chiefs       1.000000
# Las Vegas Raiders        1.000000
# Los Angeles Chargers     1.000000
# Dallas Cowboys           1.000000
# Washington Redskins      1.000000
# Name: indoor, dtype: float64

# %%
# based on this information, it looks like some of the games with missing venue data
# are non-standard games (ex. AFC, AFC All-stars, NFC, ect). We will exclude
# non-standard games and reassess which games are missing venue data

# %%
non_standard_teams = [
    "AFC", "NFC", "Afc", "Nfc",
    "AFC All-Stars", "NFC All-Stars",
    "Team Rice", "Team Carter", "Team Irvin"
]

# %%
non_standard_games = analysis_df[
    (analysis_df["home_team"].isin(non_standard_teams)) |
    (analysis_df["away_team"].isin(non_standard_teams))
]

# %%
non_standard_games.shape
# Out:
# (19, 19)

# %%
non_standard_games[["season", "season_type", "home_team", "away_team", "status"]].head(19)
# Out:
#        season  season_type      home_team      away_team        status
# 3839     2006            3            Afc            Nfc  STATUS_FINAL
# 4172     2007            3            Nfc            Afc  STATUS_FINAL
# 4505     2008            3            Afc            Nfc  STATUS_FINAL
# 4837     2009            3            Afc            Nfc  STATUS_FINAL
# 5170     2010            3            Nfc            Afc  STATUS_FINAL
# 5502     2011            3            Afc            Nfc  STATUS_FINAL
# 5835     2012            3            Nfc            Afc  STATUS_FINAL
# 6168     2013            3      Team Rice   Team Sanders  STATUS_FINAL
# 6502     2014            3    Team Carter     Team Irvin  STATUS_FINAL
# 6835     2015            3     Team Irvin      Team Rice  STATUS_FINAL
# 7167     2016            3            Nfc            Afc  STATUS_FINAL
# 7500     2017            3            Afc            Nfc  STATUS_FINAL
# 7833     2018            3  NFC All-Stars  AFC All-Stars  STATUS_FINAL
# 8166     2019            3  AFC All-Stars  NFC All-Stars  STATUS_FINAL
# 8769     2021            3            AFC            NFC  STATUS_FINAL
# 9103     2022            3            NFC            AFC  STATUS_FINAL
# 9438     2023            3            AFC            NFC  STATUS_FINAL
# 9773     2024            3            NFC            AFC  STATUS_FINAL
# 10108    2025            3            AFC            NFC  STATUS_FINAL

# %%
analysis_df = analysis_df[
    ~(
        (analysis_df["home_team"].isin(non_standard_teams)) |
        (analysis_df["away_team"].isin(non_standard_teams))
    )
]

# %%
analysis_df["home_team"].isin(non_standard_teams).sum()
# Out:
# np.int64(0)

# %%
analysis_df["away_team"].isin(non_standard_teams).sum()
# Out:
# np.int64(0)

# %%
analysis_df.groupby("home_team")["indoor"].apply(lambda x: x.notna().mean()).sort_values()
# Out:
# home_team
# Oakland Raiders          0.866071
# Indianapolis Colts       0.895349
# Miami Dolphins           0.914634
# Minnesota Vikings        0.916168
# New England Patriots     1.000000
# New Orleans Saints       1.000000
# New York Giants          1.000000
# New York Jets            1.000000
# Philadelphia Eagles      1.000000
# Arizona Cardinals        1.000000
# San Francisco 49ers      1.000000
# Seattle Seahawks         1.000000
# St. Louis Rams           1.000000
# Tampa Bay Buccaneers     1.000000
# Tennessee Titans         1.000000
# Washington               1.000000
# San Diego Chargers       1.000000
# Pittsburgh Steelers      1.000000
# Los Angeles Rams         1.000000
# Los Angeles Chargers     1.000000
# Atlanta Falcons          1.000000
# Baltimore Ravens         1.000000
# Buffalo Bills            1.000000
# Carolina Panthers        1.000000
# Chicago Bears            1.000000
# Cincinnati Bengals       1.000000
# Cleveland Browns         1.000000
# Dallas Cowboys           1.000000
# Denver Broncos           1.000000
# Detroit Lions            1.000000
# Green Bay Packers        1.000000
# Houston Texans           1.000000
# Jacksonville Jaguars     1.000000
# Kansas City Chiefs       1.000000
# Las Vegas Raiders        1.000000
# Washington Commanders    1.000000
# Washington Redskins      1.000000
# Name: indoor, dtype: float64

# %%
analysis_df["indoor"].value_counts(dropna=False)
# Out:
# indoor
# False    3886
# True     1483
# None       61
# Name: count, dtype: int64

# %%
# We still have a lot of indoor information missing from standard regular-season
# and post-season games. Next we will look at charactersitics of that missing data
# to assess if there is a trend

# %%
analysis_df[analysis_df["indoor"].isna()].groupby("season").size()
# Out:
# season
# 2006    30
# 2007    31
# dtype: int64

# %%
# It looks like the missing data is only from 2006 and 2007 and it is only from
# four teams. Next we will look up those home team stadiums to assess if they are
# indoor or outdoor to fill that information manually

# %%
# Based on a google search we discovered that during the 2006-2007 season the home
# stadiums of the Oakland Raiders and the Miami Dolphins were outdoor and the home
# stadiums of the Indianapolis Colts and Minnesota Vikings are indoor. Based on that
# information, we can fill the missing venue data and use the score data

# %%
stadium_lookup = {
    "Oakland Raiders": {
        "indoor": False,
        "venue_name": "Oakland Coliseum",
        "venue_city": "Oakland",
        "venue_state": "CA",
        "venue_country": "USA"
    },
    "Miami Dolphins": {
        "indoor": False,
        "venue_name": "Dolphin Stadium",
        "venue_city": "Miami Gardens",
        "venue_state": "FL",
        "venue_country": "USA"
    },
    "Indianapolis Colts": {
        "indoor": True,
        "venue_name": "RCA Dome",
        "venue_city": "Indianapolis",
        "venue_state": "IN",
        "venue_country": "USA"
    },
    "Minnesota Vikings": {
        "indoor": True,
        "venue_name": "Metrodome",
        "venue_city": "Minneapolis",
        "venue_state": "MN",
        "venue_country": "USA"
    }
}

# %%
# Fill missing venue + indoor data ONLY for 2006–2007 and only for specific teams,
# and ONLY where the field is currently missing (so we don't overwrite good data)

mask_0607_teams = (
    analysis_df["season"].isin([2006, 2007]) &
    analysis_df["home_team"].isin(stadium_lookup.keys())
)

# Fill INDOOR only where missing
analysis_df.loc[mask_0607_teams & analysis_df["indoor"].isna(), "indoor"] = (
    analysis_df.loc[mask_0607_teams & analysis_df["indoor"].isna(), "home_team"]
    .map(lambda t: stadium_lookup[t]["indoor"])
)

# Fill venue fields only where missing
venue_cols = ["venue_name", "venue_city", "venue_state", "venue_country"]
for col in venue_cols:
    m = mask_0607_teams & analysis_df[col].isna()
    analysis_df.loc[m, col] = (
        analysis_df.loc[m, "home_team"]
        .map(lambda t: stadium_lookup[t][col])
    )

# %%
missing_indoor_after = analysis_df["indoor"].isna().sum()
missing_venue_after = analysis_df[["venue_name", "venue_city", "venue_state", "venue_country"]].isna().any(axis=1).sum()

print("Missing indoor after fill:", missing_indoor_after)
print("Missing any venue field after fill:", missing_venue_after)
# Out:
# Missing indoor after fill: 0
# Missing any venue field after fill: 54

# %%
analysis_df.loc[analysis_df["indoor"].isna(), 
    ["season", "home_team", "away_team", "venue_name", "venue_city", "venue_state", "venue_country", "indoor"]].head(25)
# Out:
# Empty DataFrame
# Columns: [season, home_team, away_team, venue_name, venue_city, venue_state, venue_country, indoor]
# Index: []

# %%
analysis_df["indoor"].isna().sum()
# Out:
# np.int64(0)

# %%
analysis_df.groupby("home_team")["indoor"].apply(lambda x: x.notna().mean()).sort_values()
# Out:
# home_team
# Arizona Cardinals        1.0
# Minnesota Vikings        1.0
# New England Patriots     1.0
# New Orleans Saints       1.0
# New York Giants          1.0
# New York Jets            1.0
# Oakland Raiders          1.0
# Philadelphia Eagles      1.0
# Pittsburgh Steelers      1.0
# San Diego Chargers       1.0
# San Francisco 49ers      1.0
# Seattle Seahawks         1.0
# St. Louis Rams           1.0
# Tampa Bay Buccaneers     1.0
# Tennessee Titans         1.0
# Washington               1.0
# Miami Dolphins           1.0
# Washington Commanders    1.0
# Los Angeles Rams         1.0
# Las Vegas Raiders        1.0
# Atlanta Falcons          1.0
# Baltimore Ravens         1.0
# Buffalo Bills            1.0
# Carolina Panthers        1.0
# Chicago Bears            1.0
# Cincinnati Bengals       1.0
# Cleveland Browns         1.0
# Dallas Cowboys           1.0
# Denver Broncos           1.0
# Detroit Lions            1.0
# Green Bay Packers        1.0
# Houston Texans           1.0
# Indianapolis Colts       1.0
# Jacksonville Jaguars     1.0
# Kansas City Chiefs       1.0
# Los Angeles Chargers     1.0
# Washington Redskins      1.0
# Name: indoor, dtype: float64

# %%
# Now we are looking at the data we have. It looks like we have captured all the 
# NFL games from 2006 to 2025 (note that season and post-season length changed in 
# the 2021 season)

# %%
analysis_df.groupby(["season", "season_type"]).size()
# Out:
# season  season_type
# 2006    2              256
#         3               11
# 2007    2              256
#         3               11
# 2008    2              256
#         3               11
# 2009    2              256
#         3               11
# 2010    2              256
#         3               11
# 2011    2              256
#         3               11
# 2012    2              256
#         3               11
# 2013    2              256
#         3               11
# 2014    2              256
#         3               11
# 2015    2              256
#         3               11
# 2016    2              256
#         3               11
# 2017    2              256
#         3               11
# 2018    2              256
#         3               11
# 2019    2              256
#         3               11
# 2020    2              256
#         3               13
# 2021    2              272
#         3               13
# 2022    2              271
#         3               13
# 2023    2              272
#         3               13
# 2024    2              272
#         3               13
# 2025    2              272
#         3               12
# dtype: int64

# %%
analysis_df.head()
# Out:
#         game_id  season  season_type  week                      date  \
# 3572  260907023    2006            2   1.0 2006-09-08 00:30:00+00:00
# 3573  260910005    2006            2   1.0 2006-09-10 17:00:00+00:00
# 3574  260910008    2006            2   1.0 2006-09-10 17:00:00+00:00
# 3575  260910010    2006            2   1.0 2006-09-10 17:00:00+00:00
# 3576  260910012    2006            2   1.0 2006-09-10 17:00:00+00:00
#
#                 home_team           away_team  home_score  away_score  \
# 3572  Pittsburgh Steelers      Miami Dolphins          28          17
# 3573     Cleveland Browns  New Orleans Saints          14          19
# 3574        Detroit Lions    Seattle Seahawks           6           9
# 3575     Tennessee Titans       New York Jets          16          23
# 3576   Kansas City Chiefs  Cincinnati Bengals          10          23
#
#       total_points venue_id                       venue_name   venue_city  \
# 3572            45     3752                 Acrisure Stadium   Pittsburgh
# 3573            33     3679            Huntington Bank Field    Cleveland
# 3574            15     3727                       Ford Field      Detroit
# 3575            39     3810                   Nissan Stadium    Nashville
# 3576            33     3622  GEHA Field at Arrowhead Stadium  Kansas City
#
#      venue_state venue_country indoor  temperature weather        status
# 3572          PA           USA  False          NaN    None  STATUS_FINAL
# 3573          OH           USA  False          NaN    None  STATUS_FINAL
# 3574          MI           USA   True          NaN    None  STATUS_FINAL
# 3575          TN           USA  False          NaN    None  STATUS_FINAL
# 3576          MO           USA  False          NaN    None  STATUS_FINAL

# %%
# Now that we know all of our games are official and final, so we will take out the 
# "status" clumn because it is irrelevant
# We also do not need columns "game_id" and "venue_id", so we will also delete those irrelevant columns

# %%
analysis_df = analysis_df.drop(columns=["status", "game_id", "venue_id"])

# %%
analysis_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5430 entries, 3572 to 10107
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   season         5430 non-null   int64
#  1   season_type    5430 non-null   int64
#  2   week           5430 non-null   float64
#  3   date           5430 non-null   datetime64[ns, UTC]
#  4   home_team      5430 non-null   object
#  5   away_team      5430 non-null   object
#  6   home_score     5430 non-null   int64
#  7   away_score     5430 non-null   int64
#  8   total_points   5430 non-null   int64
#  9   venue_name     5430 non-null   object
#  10  venue_city     5430 non-null   object
#  11  venue_state    5376 non-null   object
#  12  venue_country  5430 non-null   object
#  13  indoor         5430 non-null   object
#  14  temperature    0 non-null      float64
#  15  weather        0 non-null      object
# dtypes: datetime64[ns, UTC](1), float64(2), int64(5), object(8)
# memory usage: 721.2+ KB

# %%
# Our information is now complete for all columns except for weather information 
# under the columns "temperature" and "weather"

# %%
# Our original goal was to project the total score for the superbowl, but because the 
# superbowl is going to be played in an outdoor stadium, we will need weather data. 
# To fill that informtaion we will need to import weather data.

# %%
analysis_df.head()
# Out:
#       season  season_type  week                      date  \
# 3572    2006            2   1.0 2006-09-08 00:30:00+00:00
# 3573    2006            2   1.0 2006-09-10 17:00:00+00:00
# 3574    2006            2   1.0 2006-09-10 17:00:00+00:00
# 3575    2006            2   1.0 2006-09-10 17:00:00+00:00
# 3576    2006            2   1.0 2006-09-10 17:00:00+00:00
#
#                 home_team           away_team  home_score  away_score  \
# 3572  Pittsburgh Steelers      Miami Dolphins          28          17
# 3573     Cleveland Browns  New Orleans Saints          14          19
# 3574        Detroit Lions    Seattle Seahawks           6           9
# 3575     Tennessee Titans       New York Jets          16          23
# 3576   Kansas City Chiefs  Cincinnati Bengals          10          23
#
#       total_points                       venue_name   venue_city venue_state  \
# 3572            45                 Acrisure Stadium   Pittsburgh          PA
# 3573            33            Huntington Bank Field    Cleveland          OH
# 3574            15                       Ford Field      Detroit          MI
# 3575            39                   Nissan Stadium    Nashville          TN
# 3576            33  GEHA Field at Arrowhead Stadium  Kansas City          MO
#
#      venue_country indoor  temperature weather
# 3572           USA  False          NaN    None
# 3573           USA  False          NaN    None
# 3574           USA   True          NaN    None
# 3575           USA  False          NaN    None
# 3576           USA  False          NaN    None

# %%
# Looking at our data now, the next bigest gap in our data is location information
# So we will analyze which the rows with missing location data to see if theres a trend

# %%
analysis_df["venue_missing"] = (
    analysis_df["venue_name"].isna() |
    analysis_df["venue_city"].isna() |
    analysis_df["venue_state"].isna() |
    analysis_df["venue_country"].isna()
)

# %%
analysis_df.groupby("season")["venue_missing"].sum().sort_values()
# Out:
# season
# 2006    0
# 2007    0
# 2020    0
# 2008    1
# 2009    1
# 2010    1
# 2011    1
# 2012    1
# 2013    2
# 2021    2
# 2018    3
# 2015    3
# 2014    3
# 2016    4
# 2019    5
# 2024    5
# 2022    5
# 2023    5
# 2017    5
# 2025    7
# Name: venue_missing, dtype: int64

# %%
# It looks like there are 54 games with missing venue data and based on the info summary, it is only venue_state
# We suspect that it is only for special events in foreign countries, but we will confirm

# %%
missing_location_df = analysis_df[analysis_df["venue_missing"]]

missing_location_df.shape
# Out:
# (54, 17)

# %%
missing_location_df["venue_country"].value_counts(dropna=False)
# Out:
# venue_country
# England    41
# Germany     5
# Mexico      4
# Brazil      2
# Ireland     1
# Spain       1
# Name: count, dtype: int64

# %%
missing_location_df[
    ["season", "week", "home_team", "away_team",
     "venue_name", "venue_city", "venue_state", "venue_country", "indoor"]
].sort_values(["season", "week"]).sample(15)
# Out:
#       season  week             home_team             away_team  \
# 5014    2010   8.0   San Francisco 49ers        Denver Broncos
# 8929    2022   8.0  Jacksonville Jaguars        Denver Broncos
# 9490    2024   1.0   Philadelphia Eagles     Green Bay Packers
# 7282    2017   4.0        Miami Dolphins    New Orleans Saints
# 6375    2014  10.0  Jacksonville Jaguars        Dallas Cowboys
# 8061    2019  11.0  Los Angeles Chargers    Kansas City Chiefs
# 4665    2009   7.0  Tampa Bay Buccaneers  New England Patriots
# 7979    2019   6.0  Tampa Bay Buccaneers     Carolina Panthers
# 6675    2015   8.0    Kansas City Chiefs         Detroit Lions
# 8983    2022  11.0     Arizona Cardinals   San Francisco 49ers
# 8885    2022   5.0     Green Bay Packers       New York Giants
# 9582    2024   7.0  Jacksonville Jaguars  New England Patriots
# 7391    2017  11.0       Oakland Raiders  New England Patriots
# 6950    2016   4.0  Jacksonville Jaguars    Indianapolis Colts
# 9918    2025   7.0  Jacksonville Jaguars      Los Angeles Rams
#
#                      venue_name   venue_city venue_state venue_country indoor
# 5014            Wembley Stadium       London        None       England  False
# 8929            Wembley Stadium       London        None       England  False
# 9490          Corinthians Arena    Sao Paulo        None        Brazil  False
# 7282            Wembley Stadium       London        None       England  False
# 6375            Wembley Stadium       London        None       England  False
# 8061             Estadio Azteca  Mexico City        None        Mexico  False
# 4665            Wembley Stadium       London        None       England  False
# 7979  Tottenham Hotspur Stadium       London        None       England  False
# 6675            Wembley Stadium       London        None       England  False
# 8983             Estadio Azteca  Mexico City        None        Mexico  False
# 8885  Tottenham Hotspur Stadium       London        None       England  False
# 9582            Wembley Stadium       London        None       England  False
# 7391             Estadio Azteca  Mexico City        None        Mexico  False
# 6950            Wembley Stadium       London        None       England  False
# 9918            Wembley Stadium       London        None       England  False

# %%
# We confimed that the only location data missing is the state name for international games, however that is not an
# error since international countries do not have states

# %%
# We still want to use information on weather data to find games similar to the conditions for the superbowl, but we
# do not have weather data yet, so we will start to get that information. We will start by getting a longitude and latitude for
# each venue

# %%
# First we will get information on every unique location where a game was played

# %%
analysis_df["venue_key"] = (
    analysis_df["venue_name"].fillna("").astype(str).str.strip() + " | " +
    analysis_df["venue_city"].fillna("").astype(str).str.strip() + " | " +
    analysis_df["venue_country"].fillna("").astype(str).str.strip()
)

venues_df = (
    analysis_df[["venue_key", "venue_name", "venue_city", "venue_country"]]
    .drop_duplicates()
    .reset_index(drop=True)
)

venues_df["venue_query"] = (
    venues_df["venue_name"].fillna("").astype(str).str.strip() + ", " +
    venues_df["venue_city"].fillna("").astype(str).str.strip() + ", " +
    venues_df["venue_country"].fillna("").astype(str).str.strip()
)

# %%
venues_df.head()
# Out:
#                                            venue_key  \
# 0                Acrisure Stadium | Pittsburgh | USA
# 1            Huntington Bank Field | Cleveland | USA
# 2                         Ford Field | Detroit | USA
# 3                   Nissan Stadium | Nashville | USA
# 4  GEHA Field at Arrowhead Stadium | Kansas City ...
#
#                         venue_name   venue_city venue_country  \
# 0                 Acrisure Stadium   Pittsburgh           USA
# 1            Huntington Bank Field    Cleveland           USA
# 2                       Ford Field      Detroit           USA
# 3                   Nissan Stadium    Nashville           USA
# 4  GEHA Field at Arrowhead Stadium  Kansas City           USA
#
#                                          venue_query
# 0                  Acrisure Stadium, Pittsburgh, USA
# 1              Huntington Bank Field, Cleveland, USA
# 2                           Ford Field, Detroit, USA
# 3                     Nissan Stadium, Nashville, USA
# 4  GEHA Field at Arrowhead Stadium, Kansas City, USA

# %%
venues_df["venue_query"].sort_values()
# Out:
# 38                         AT&T Stadium, Arlington, USA
# 0                     Acrisure Stadium, Pittsburgh, USA
# 50                    Allegiant Stadium, Las Vegas, USA
# 51                       Allianz Arena, Munich, Germany
# 8               Bank of America Stadium, Charlotte, USA
# 30                  Caesars Superdome, New Orleans, USA
# 33                 Candlestick Park, San Francisco, USA
# 53                 Corinthians Arena, Sao Paulo, Brazil
# 54                          Croke Park, Dublin, Ireland
# 46              Dignity Health Sports Park, Carson, USA
# 20                  Dolphin Stadium, Miami Gardens, USA
# 31              Empower Field at Mile High, Denver, USA
# 45                  Estadio Azteca, Mexico City, Mexico
# 12                  EverBank Stadium, Jacksonville, USA
# 2                              Ford Field, Detroit, USA
# 52                Frankfurt Stadium, Frankfurt, Germany
# 4     GEHA Field at Arrowhead Stadium, Kansas City, USA
# 16                           Georgia Dome, Atlanta, USA
# 13                 Giants Stadium, East Rutherford, USA
# 6                     Gillette Stadium, Foxborough, USA
# 32                Hard Rock Stadium, Miami Gardens, USA
# 29                  Highmark Stadium, Orchard Park, USA
# 1                 Huntington Bank Field, Cleveland, USA
# 40            Huntington Bank Stadium, Minneapolis, USA
# 26                           Invesco Field, Denver, USA
# 10                        Lambeau Field, Green Bay, USA
# 41                     Levi's Stadium, Santa Clara, USA
# 22           Lincoln Financial Field, Philadelphia, USA
# 42      Los Angeles Memorial Coliseum, Los Angeles, USA
# 35                 Lucas Oil Stadium, Indianapolis, USA
# 25                            Lumen Field, Seattle, USA
# 23                     M&T Bank Stadium, Baltimore, USA
# 36              Mall of America Field, Minneapolis, USA
# 47                  Mercedes-Benz Stadium, Atlanta, USA
# 39                MetLife Stadium, East Rutherford, USA
# 21                          Metrodome, Minneapolis, USA
# 24                     Monster Park, San Francisco, USA
# 9                             NRG Stadium, Houston, USA
# 3                        Nissan Stadium, Nashville, USA
# 14                     Northwest Stadium, Landover, USA
# 15                       Oakland Coliseum, Oakland, USA
# 55              Olympic Stadium Berlin, Berlin, Germany
# 18                      Paycor Stadium, Cincinnati, USA
# 19                          RCA Dome, Indianapolis, USA
# 7                     Raymond James Stadium, Tampa, USA
# 37                       Rogers Centre, Toronto, Canada
# 27                        SDCCU Stadium, San Diego, USA
# 56                     Santiago Bernabéu, Madrid, Spain
# 49                         SoFi Stadium, Inglewood, USA
# 17                          Soldier Field, Chicago, USA
# 11                    State Farm Stadium, Glendale, USA
# 28                           Texas Stadium, Irving, USA
# 5          The Dome at America's Center, St. Louis, USA
# 48           Tottenham Hotspur Stadium, London, England
# 44                  Twickenham Stadium, London, England
# 43                  U.S. Bank Stadium, Minneapolis, USA
# 34                     Wembley Stadium, London, England
# Name: venue_query, dtype: object

# %%
# Okay now that we have all the unique locations that hosted games we will pull longitude and latitude information so that
# we can pull weather data later

# %%
import time
import requests

def geocode_nominatim(query: str, pause_s=1.1):

    url = "https://nominatim.openstreetmap.org/search"
    params = {"q": query, "format": "json", "limit": 1}
    headers = {"User-Agent": "booth-nfl-weather-project/1.0 (contact: rnunez0@chicagobooth.edu)"}

    time.sleep(pause_s)
    r = requests.get(url, params=params, headers=headers, timeout=30)
    r.raise_for_status()
    out = r.json()

    if not out:
        return None, None, None

    return float(out[0]["lat"]), float(out[0]["lon"]), out[0].get("display_name")

# Making a copy so we don't overwrite accidentally
venues_geo_df = venues_df.copy()

# Fill lat/lon
results = venues_geo_df["venue_query"].apply(lambda q: geocode_nominatim(q))
venues_geo_df[["lat", "lon", "geocode_label"]] = list(results)

# %%
venues_geo_df[["venue_query", "lat", "lon", "geocode_label"]].head()
# Out:
#                                          venue_query        lat        lon  \
# 0                  Acrisure Stadium, Pittsburgh, USA  40.446717  -80.01572
# 1              Huntington Bank Field, Cleveland, USA  41.506056 -81.699712
# 2                           Ford Field, Detroit, USA  42.339957 -83.045617
# 3                     Nissan Stadium, Nashville, USA  36.166524 -86.771315
# 4  GEHA Field at Arrowhead Stadium, Kansas City, USA  39.048931 -94.483999
#
#                                        geocode_label
# 0  Acrisure Stadium, Art Rooney Avenue, North Sho...
# 1  Huntington Bank Field, 100, Alfred Lerner Way,...
# 2  Ford Field, Saint Antoine Street, Greektown, M...
# 3  Nissan Stadium, 1, Titans Way, East Nashville,...
# 4  GEHA Field at Arrowhead Stadium, Red Coat Driv...

# %%
# We were able to pull long and lat for our venues, now I am going to add the information to full dataframe

# %%
analysis_df = analysis_df.merge(
    venues_geo_df[["venue_key", "lat", "lon"]],
    on="venue_key",
    how="left"
)

# %%
analysis_df[["venue_name", "venue_city", "venue_country", "lat", "lon"]].head()
# Out:
#                         venue_name   venue_city venue_country        lat  \
# 0                 Acrisure Stadium   Pittsburgh           USA  40.446717
# 1            Huntington Bank Field    Cleveland           USA  41.506056
# 2                       Ford Field      Detroit           USA  42.339957
# 3                   Nissan Stadium    Nashville           USA  36.166524
# 4  GEHA Field at Arrowhead Stadium  Kansas City           USA  39.048931
#
#          lon
# 0  -80.01572
# 1 -81.699712
# 2 -83.045617
# 3 -86.771315
# 4 -94.483999

# %%
analysis_df[["lat","lon"]].isna().sum()
# Out:
# lat    354
# lon    354
# dtype: int64

# %%
# It looks like we have some locations without long/lat data, so we will look into 
# what is missing

# %%
venues_geo_df["lat"].isna().sum()
# Out:
# np.int64(7)

# %%
venues_geo_df[venues_geo_df["lat"].isna()]
# Out:
#                                     venue_key             venue_name  \
# 13     Giants Stadium | East Rutherford | USA         Giants Stadium
# 16               Georgia Dome | Atlanta | USA           Georgia Dome
# 19              RCA Dome | Indianapolis | USA               RCA Dome
# 24         Monster Park | San Francisco | USA           Monster Park
# 27            SDCCU Stadium | San Diego | USA          SDCCU Stadium
# 28               Texas Stadium | Irving | USA          Texas Stadium
# 36  Mall of America Field | Minneapolis | USA  Mall of America Field
#
#          venue_city venue_country                              venue_query  \
# 13  East Rutherford           USA     Giants Stadium, East Rutherford, USA
# 16          Atlanta           USA               Georgia Dome, Atlanta, USA
# 19     Indianapolis           USA              RCA Dome, Indianapolis, USA
# 24    San Francisco           USA         Monster Park, San Francisco, USA
# 27        San Diego           USA            SDCCU Stadium, San Diego, USA
# 28           Irving           USA               Texas Stadium, Irving, USA
# 36      Minneapolis           USA  Mall of America Field, Minneapolis, USA
#
#     lat  lon geocode_label
# 13  NaN  NaN          None
# 16  NaN  NaN          None
# 19  NaN  NaN          None
# 24  NaN  NaN          None
# 27  NaN  NaN          None
# 28  NaN  NaN          None
# 36  NaN  NaN          None

# %%
# We only have 7 unique location missing so we will manually fill it in

# %%
manual_latlon = {
    "Giants Stadium | East Rutherford | USA": (40.8128, -74.0742),
    "Georgia Dome | Atlanta | USA": (33.7580, -84.4010),
    "RCA Dome | Indianapolis | USA": (39.7601, -86.1639),
    "Monster Park | San Francisco | USA": (37.7786, -122.3893),
    "SDCCU Stadium | San Diego | USA": (32.7831, -117.1195),
    "Texas Stadium | Irving | USA": (32.8387, -96.9119),
    "Mall of America Field | Minneapolis | USA": (44.9737, -93.2577),
}

# %%
import re

manual_latlon_norm = {
    re.sub(r"\s+", " ", re.sub(r"\s*\|\s*", " | ", str(k))).strip(): v
    for k, v in manual_latlon.items()
}

# %%
# We're normalizing venue_key formatting to make dictionary matching reliable
venues_geo_df["venue_key_norm"] = (
    venues_geo_df["venue_key"]
    .astype(str)
    .str.replace(r"\s*\|\s*", " | ", regex=True)  # normalize pipe spacing
    .str.replace(r"\s+", " ", regex=True)         # collapse weird whitespace
    .str.strip()
)

# %%
analysis_df = (
    analysis_df
    .drop(columns=["lat", "lon"], errors="ignore")
    .merge(
        venues_geo_df[["venue_key", "lat", "lon"]],
        on="venue_key",
        how="left"
    )
)

# %%
mask_missing_latlon = (
    venues_geo_df["venue_key_norm"].isin(manual_latlon_norm.keys()) &
    venues_geo_df["lat"].isna() &
    venues_geo_df["lon"].isna()
)

# %%
tmp = venues_geo_df.loc[mask_missing_latlon, "venue_key_norm"].map(manual_latlon_norm)

venues_geo_df.loc[mask_missing_latlon, "lat"] = tmp.apply(lambda x: x[0])
venues_geo_df.loc[mask_missing_latlon, "lon"] = tmp.apply(lambda x: x[1])

# %%
venues_geo_df[["lat", "lon"]].isna().sum()
# Out:
# lat    0
# lon    0
# dtype: int64

# %%
venues_geo_df.loc[mask_missing_latlon, "venue_key_norm"].map(manual_latlon_norm).isna().sum()
# Out:
# np.int64(0)

# %%
# We now confirmed that we have longitude and latitide information for all
# unique locations. Next we will start pulling weeather data for those locations

# %%
weather_requests_df = (
    analysis_df
    .assign(date=lambda df: df["date"].dt.date)
    [["date", "lat", "lon"]]
    .dropna(subset=["lat", "lon"])
    .drop_duplicates()
    .reset_index(drop=True)
)

# %%
import requests

def fetch_weather_daily(lat, lon, date):
    url = "https://archive-api.open-meteo.com/v1/archive"
    params = {
        "latitude": lat,
        "longitude": lon,
        "start_date": date,
        "end_date": date,
        "daily": "temperature_2m_mean,rain_sum,windspeed_10m_mean,snowfall_sum",
        "timezone": "UTC",
    }

    r = requests.get(url, params=params, timeout=30)
    r.raise_for_status()
    data = r.json()

    return {
        "avg_temp": data["daily"]["temperature_2m_mean"][0],
        "rain_sum": data["daily"]["rain_sum"][0],
        "wind_speed_avg": data["daily"]["windspeed_10m_mean"][0],
        "snowfall_sum": data["daily"]["snowfall_sum"][0],
    }

# %%
row = weather_requests_df.iloc[0]
fetch_weather_daily(row["lat"], row["lon"], row["date"].isoformat())
# Out:
# {'avg_temp': 19.6, 'rain_sum': 0.0, 'wind_speed_avg': 4.1, 'snowfall_sum': 0.0}

# %%
# It looks like the weather data request worked, next we're going to test with a
# sample of 5 locations

# %%
test_weather = (
    weather_requests_df
    .head(5)
    .apply(lambda r: fetch_weather_daily(r["lat"], r["lon"], r["date"].isoformat()), axis=1))

        
pd.DataFrame(list(test_weather))
# Out:
#    avg_temp  rain_sum  wind_speed_avg  snowfall_sum
# 0      19.6       0.0             4.1           0.0
# 1      18.8       0.1            16.2           0.0
# 2      15.7       0.1            19.6           0.0
# 3      24.7       0.5             5.9           0.0
# 4      21.6       1.0            10.7           0.0

# %%
# It worked, so now we will scale up to include weather data for all our unique locations
# for 2006 season until now

# %%
weather_requests_df.shape
# Out:
# (5075, 3)

# %%
import time

results = []
n = len(weather_requests_df)

for i, r in weather_requests_df.iterrows():
    out = fetch_weather_daily(r["lat"], r["lon"], r["date"].isoformat())
    results.append(out)

    # simple progress print every 1000 requests
    if (i + 1) % 1000 == 0 or (i + 1) == n:
        print(f"Pulled {i+1}/{n} weather rows")

    # free API denies high volume of requests, so set limit to slow requests
    time.sleep(0.25)

weather_df = pd.DataFrame(results)
weather_df = pd.concat([weather_requests_df[["date", "lat", "lon"]], weather_df], axis=1)

weather_df.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[127], line 7
#       4 n = len(weather_requests_df)
#       6 for i, r in weather_requests_df.iterrows():
# ----> 7     out = fetch_weather_daily(r["lat"], r["lon"], r["date"].isoformat())
#       8     results.append(out)
#      10     # simple progress print every 1000 requests
#
# Cell In[120], line 15, in fetch_weather_daily(lat, lon, date)
#       5 params = {
#       6     "latitude": lat,
#       7     "longitude": lon,
#    (...)     11     "timezone": "UTC",
#      12 }
#      14 r = requests.get(url, params=params, timeout=30)
# ---> 15 r.raise_for_status()
#      16 data = r.json()
#      18 return {
#      19     "avg_temp": data["daily"]["temperature_2m_mean"][0],
#      20     "rain_sum": data["daily"]["rain_sum"][0],
#      21     "wind_speed_avg": data["daily"]["windspeed_10m_mean"][0],
#      22     "snowfall_sum": data["daily"]["snowfall_sum"][0],
#      23 }
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=40.4467166&longitude=-80.0157199&start_date=2006-09-08&end_date=2006-09-08&daily=temperature_2m_mean%2Crain_sum%2Cwindspeed_10m_mean%2Csnowfall_sum&timezone=UTC

# %%
# Now that we have weather data for all out games, we will merge the data back with
# the full game data set. Because of previous errors, I am going to make sure both
# data frames have the same data format

# %%
# Create a pure date key on analysis_df
analysis_df["game_day"] = analysis_df["date"].dt.date

# %%
# Ensure weather_df date key is also a pure date
weather_df["game_day"] = pd.to_datetime(weather_df["date"]).dt.date

# %%
# If you already merged once, clear weather cols so re-running doesn't create duplicates
# This is because the merged df would result in errors when we re-ran code during eda
weather_cols = ["avg_temp", "rain_sum", "wind_speed_avg", "snowfall_sum"]
analysis_df = analysis_df.drop(columns=[c for c in weather_cols if c in analysis_df.columns], errors="ignore")
analysis_df = analysis_df.drop(columns=[c for c in ["game_day"] if c in analysis_df.columns], errors="ignore")

# %%
# Merge on consistent keys
analysis_df["game_day"] = analysis_df["date"].dt.date
weather_df["game_day"] = pd.to_datetime(weather_df["date"]).dt.date

analysis_df = analysis_df.merge(
    weather_df[["game_day", "lat", "lon", "avg_temp", "rain_sum", "wind_speed_avg", "snowfall_sum"]],
    on=["game_day", "lat", "lon"],
    how="left"
)

# %%
# Next I am going to make sure there is no missing data

# %%
analysis_df[["avg_temp", "rain_sum", "wind_speed_avg", "snowfall_sum"]].isna().sum()

# %%
# Quick data distribution check
analysis_df[["avg_temp", "rain_sum", "wind_speed_avg", "snowfall_sum"]].describe()

# %%
# Looking at this data the temps dont make sense, so it must be in Celsius, so we
# are going to convert it to Fahrenheit

# %%
analysis_df["avg_temp"] = analysis_df["avg_temp"] * 9/5 + 32

# %%
# No going to double check temp data
analysis_df[["avg_temp"]].describe()

# %%
analysis_df.sample(10)

# %%
# Looking back at total data we see a lot of columns of data, so we are going to look
# at all the columns to identify what we need

# %%
analysis_df.columns.tolist()

# %%
# There is a lot of redundant columns so I am going to drop columns to only what I need

# %%
cols_to_drop = [
    "temperature",
    "weather",
    "venue_missing",
    "venue_key",
    "avg_temp_x",
    "rain_sum_x",
    "wind_speed_avg_x",
    "snowfall_sum_x",
    "avg_temp_y",
    "rain_sum_y",
    "wind_speed_avg_y",
    "snowfall_sum_y",
    "avg_temp_f",
    "game_day",
]

analysis_df = analysis_df.drop(columns=cols_to_drop, errors="ignore")

# %%
analysis_df.columns.tolist()

# %%
# In assessing our columns we think it would make sense to add information that will
# help us assess the affect weather has on total score. For example, we will make rain
# and snow binary conditions by making two new columns named "rain_any" and "snow_any"

# %%
# Next we will clarify the title of "indoor" to clearly show its means, was the game
# in a indoor arena. To do this we will change the name to "is_indoor" and convert
# string to bool

# %%
analysis_df["is_indoor"] = (
    analysis_df["indoor"]
    .astype(str)
    .str.lower()
    .isin(["true", "1", "yes"])
)

analysis_df["rain_any"] = analysis_df["rain_sum"] > 0
analysis_df["snow_any"] = analysis_df["snowfall_sum"] > 0

# %%
analysis_df.info()

# %%
# Now that we have all the information we need, I am going to start to identify if
# weather affects the total points scored in a football game by comparing averages of 
# indoor and outdoor games

# %%
analysis_df.groupby("is_indoor")["total_points"].describe()

# %%
# Next we will find if the difference is statistically significant

# %%
import scipy
from scipy.stats import ttest_ind

indoor = analysis_df.loc[analysis_df["is_indoor"], "total_points"]
outdoor = analysis_df.loc[~analysis_df["is_indoor"], "total_points"]

ttest_ind(indoor, outdoor, equal_var=False)

# %%
# Now that we know outdoor games have lower average points scored, we can assume that
# weather has an affect, so we will isolate data for games that were played outside
# to explore affect of different kinds of weather in more detail

# %%
# To create a df with just games affected by weather

# %%
outdoor_df = analysis_df[analysis_df["is_indoor"] == False]

# %%
outdoor_df.shape

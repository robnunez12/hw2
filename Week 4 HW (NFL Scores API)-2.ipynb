# %%
# I am going to use an API from ESPN to pull regular season scores and results for the NFL.
# I inspect and clean the data to pull a couple insights from the data

# %%
import requests
import json
from pprint import pprint
import pandas as pd

# %%
response = requests.get("https://site.api.espn.com/apis/site/v2/sports/football/nfl/scoreboard")
print(response.status_code)
# Out:
# 200

# %%
print(response.json())
# Out:
# {'leagues': [{'id': '28', 'uid': 's:20~l:28', 'name': 'National Football League', 'abbreviation': 'NFL', 'slug': 'nfl', 'season': {'year': 2025, 'startDate': '2025-07-31T07:00Z', 'endDate': '2026-02-12T07:59Z', 'displayName': '2025', 'type': {'id': '3', 'type': 3, 'name': 'Postseason', 'abbreviation': 'post'}}, 'logos': [{'href': 'https://a.espncdn.com/i/teamlogos/leagues/500/nfl.png', 'width': 500, 'height': 500, 'alt': '', 'rel': ['full', 'default'], 'lastUpdated': '2018-06-05T12:07Z'}, {'href': 'https://a.espncdn.com/i/teamlogos/leagues/500-dark/nfl.png', 'width': 500, 'height': 500, 'alt': '', 'rel': ['full', 'dark'], 'lastUpdated': '2024-07-22T16:53Z'}], 'calendarType': 'list', 'calendarIsWhitelist': True, 'calendarStartDate': '2025-07-31T07:00Z', 'calendarEndDate': '2026-02-12T07:59Z', 'calendar': [{'label': 'Preseason', 'value': '1', 'startDate': '2025-07-31T07:00Z', 'endDate': '2025-09-04T06:59Z', 'entries': [{'label': 'Hall of Fame Weekend', 'alternateLabel': 'HOF', 'detail': 'Jul 31-Aug 6', 'value': '1', 'startDate': '2025-07-31T07:00Z', 'endDate': '2025-08-07T06:59Z'}, {'label': 'Preseason Week 1', 'alternateLabel': 'Pre Wk 1', 'detail': 'Aug 7-13', 'value': '2', 'startDate': '2025-08-07T07:00Z', 'endDate': '2025-08-14T06:59Z'}, {'label': 'Preseason Week 2', 'alternateLabel': 'Pre Wk 2', 'detail': 'Aug 14-20', 'value': '3', 'startDate': '2025-08-14T07:00Z', 'endDate': '2025-08-21T06:59Z'}, {'label': 'Preseason Week 3', 'alternateLabel': 'Pre Wk 3', 'detail': 'Aug 21-Sep 3', 'value': '4', 'startDate': '2025-08-21T07:00Z', 'endDate': '2025-09-04T06:59Z'}]}, {'label': 'Regular Season', 'value': '2', 'startDate': '2025-09-04T07:00Z', 'endDate': '2026-01-07T07:59Z', 'entries': [{'label': 'Week 1', 'alternateLabel': 'Week 1', 'detail': 'Sep 4-9', 'value': '1', 'startDate': '2025-09-04T07:00Z', 'endDate': '2025-09-10T06:59Z'}, {'label': 'Week 2', 'alternateLabel': 'Week 2', 'detail': 'Sep 10-16', 'value': '2', 'startDate': '2025-09-10T07:00Z', 'endDate': '2025-09-17T06:59Z'}, {'label': 'Week 3', 'alternateLabel': 'Week 3', 'detail': 'Sep 17-23', 'value': '3', 'startDate': '2025-09-17T07:00Z', 'endDate': '2025-09-24T06:59Z'}, {'label': 'Week 4', 'alternateLabel': 'Week 4', 'detail': 'Sep 24-30', 'value': '4', 'startDate': '2025-09-24T07:00Z', 'endDate': '2025-10-01T06:59Z'}, {'label': 'Week 5', 'alternateLabel': 'Week 5', 'detail': 'Oct 1-7', 'value': '5', 'startDate': '2025-10-01T07:00Z', 'endDate': '2025-10-08T06:59Z'}, {'label': 'Week 6', 'alternateLabel': 'Week 6', 'detail': 'Oct 8-14', 'value': '6', 'startDate': '2025-10-08T07:00Z', 'endDate': '2025-10-15T06:59Z'}, {'label': 'Week 7', 'alternateLabel': 'Week 7', 'detail': 'Oct 15-21', 'value': '7', 'startDate': '2025-10-15T07:00Z', 'endDate': '2025-10-22T06:59Z'}, {'label': 'Week 8', 'alternateLabel': 'Week 8', 'detail': 'Oct 22-28', 'value': '8', 'startDate': '2025-10-22T07:00Z', 'endDate': '2025-10-29T06:59Z'}, {'label': 'Week 9', 'alternateLabel': 'Week 9', 'detail': 'Oct 29-Nov 4', 'value': '9', 'startDate': '2025-10-29T07:00Z', 'endDate': '2025-11-05T07:59Z'}, {'label': 'Week 10', 'alternateLabel': 'Week 10', 'detail': 'Nov 5-11', 'value': '10', 'startDate': '2025-11-05T08:00Z', 'endDate': '2025-11-12T07:59Z'}, {'label': 'Week 11', 'alternateLabel': 'Week 11', 'detail': 'Nov 12-18', 'value': '11', 'startDate': '2025-11-12T08:00Z', 'endDate': '2025-11-19T07:59Z'}, {'label': 'Week 12', 'alternateLabel': 'Week 12', 'detail': 'Nov 19-25', 'value': '12', 'startDate': '2025-11-19T08:00Z', 'endDate': '2025-11-26T07:59Z'}, {'label': 'Week 13', 'alternateLabel': 'Week 13', 'detail': 'Nov 26-Dec 2', 'value': '13', 'startDate': '2025-11-26T08:00Z', 'endDate': '2025-12-03T07:59Z'}, {'label': 'Week 14', 'alternateLabel': 'Week 14', 'detail': 'Dec 3-9', 'value': '14', 'startDate': '2025-12-03T08:00Z', 'endDate': '2025-12-10T07:59Z'}, {'label': 'Week 15', 'alternateLabel': 'Week 15', 'detail': 'Dec 10-16', 'value': '15', 'startDate': '2025-12-10T08:00Z', 'endDate': '2025-12-17T0 ...

# %%
pprint(response.json())
# Out:
# {'events': [{'competitions': [{'attendance': 0,
#                                'broadcast': 'ESPN/DISNEY XD',
#                                'broadcasts': [{'market': 'national',
#                                                'names': ['ESPN', 'DISNEY XD']}],
#                                'competitors': [{'homeAway': 'home',
#                                                 'id': '31',
#                                                 'order': 0,
#                                                 'score': '0',
#                                                 'statistics': [],
#                                                 'team': {'abbreviation': 'AFC',
#                                                          'displayName': 'AFC',
#                                                          'id': '31',
#                                                          'isActive': False,
#                                                          'links': [],
#                                                          'location': 'AFC',
#                                                          'logo': 'https://a.espncdn.com/i/teamlogos/nfl/500/scoreboard/afc.png',
#                                                          'shortDisplayName': 'AFC',
#                                                          'uid': 's:20~l:28~t:31'},
#                                                 'type': 'team',
#                                                 'uid': 's:20~l:28~t:31'},
#                                                {'homeAway': 'away',
#                                                 'id': '32',
#                                                 'order': 1,
#                                                 'score': '0',
#                                                 'statistics': [],
#                                                 'team': {'abbreviation': 'NFC',
#                                                          'displayName': 'NFC',
#                                                          'id': '32',
#                                                          'isActive': False,
#                                                          'links': [],
#                                                          'location': 'NFC',
#                                                          'logo': 'https://a.espncdn.com/i/teamlogos/nfl/500/scoreboard/nfc.png',
#                                                          'shortDisplayName': 'NFC',
#                                                          'uid': 's:20~l:28~t:32'},
#                                                 'type': 'team',
#                                                 'uid': 's:20~l:28~t:32'}],
#                                'conferenceCompetition': False,
#                                'date': '2026-02-04T01:00Z',
#                                'format': {'regulation': {'periods': 4}},
#                                'geoBroadcasts': [{'lang': 'en',
#                                                   'market': {'id': '1',
#                                                              'type': 'National'},
#                                                   'media': {'darkLogo': '',
#                                                             'logo': 'https://a.espncdn.com/guid/335fd2d2-97b9-336b-81ee-573eb6bdcffc/logos/default.png',
#                                                             'shortName': 'ESPN'},
#                                                   'region': 'us',
#                                                   'type': {'id': '1',
#                                                            'shortName': 'TV'}},
#                                                  {'lang': 'en',
#                                                   'market': {'id': '1',
#                                                              'type': 'National'},
#                                                   'media': {'shortName': 'DISNEY '
#                                                                          'XD'},
#                                                   'region': 'us',
#                                                   'type': {'id': '1',
#                                                            'shortName': 'TV'}}],
#                                'highlights': [],
#                                'id': '401831718',
#                                'neutralSite': True,
#                                'notes': [{'headline': 'Pro Bowl Games',
#                                           'type': 'event'}],
#                                'playByPlayAvailable': False,
#                                'recent': False,
#                                'startDate': '2026-02-04T01:00Z',
#                                'status': {'clock': 0.0,
#                                           'displayClock': '0:00',
#                                           'isTBDFlex': False,
#                                           'period': 0,
#                                           'type': {'completed': False,
#                                                    'description': 'Scheduled',
#                                                    'detail': 'Tue, February '
#                                                              '3rd at 8:00 PM '
#                                                              'EST',
#                                                    'id': '1',
#                                                    'name': 'STATUS_SCHEDULED',
#                                                    'shortDetail': '2/3 - 8:00 '
#                                                                   'PM EST',
#                                                    'state': 'pre'}},
#                                'tickets': [{'links': [{'href': 'https://www.vividseats.com/nfl-pro-bowl-tickets-moscone-center-2-3-2026--sports-nfl-football/production/6513292?wsUser=717'},
#                                                       {'href': 'https://www.vividseats.com/venues/moscone-center-tickets.html?wsUser=717'}],
#                                             'numberAvailable': 10,
#                                             'summary': 'Tickets as low as '
#                                                        '$76'}],
#                                'timeValid': True,
#                                'type': {'abbreviation': 'ALLSTAR', 'id': '4'},
#                                'uid': 's:20~l:28~e:401831718~c:401831718',
#                                'venue': {'address': {'city': 'San Francisco',
#                                                      'country': 'USA',
#                                                      'state': 'CA'},
#                                          'fullName': 'Moscone Center',
#                                          'id': '11634',
#                                          'indoor': True}}],
#              'date': '2026-02-04T01:00Z',
#              'id': '401831718',
#              'links': [{'href': 'https://www.espn.com/nfl/game/_/gameId/401831718/nfc-afc',
#                         'isExternal': False,
#                         'isPremium': False,
#                         'language': 'en-US',
#                         'rel': ['summary', 'desktop', 'event'],
#                         'shortText': 'Gamecast',
#                         'text': 'Gamecast'}],
#              'name': 'NFC  at AFC ',
#              'season': {'slug': 'post-season', 'type': 3, 'year': 2025},
#              'shortName': 'NFC VS AFC',
#              'status': {'clock': 0.0,
#                         'displayClock': '0:00',
#                         'period': 0,
#                         'type': {'completed': False,
#                                  'description': 'Scheduled',
#                                  'detail': 'Tue, February 3rd at 8:00 PM EST',
#                                  'id': '1',
#                                  'name': 'STATUS_SCHEDULED',
#                                  'shortDetail': '2/3 - 8:00 PM EST',
#                                  'state': 'pre'}},
#              'uid': 's:20~l:28~e:401831718',
#              'weather': {'conditionId': '2',
#                          'displayValue': 'Mostly sunny',
#                          'highTemperature': 66,
#                          'temperature': 66},
#              'week': {'number': 4}}],
#  'leagues': [{'abbreviation': 'NFL',
#               'calendar': [{'endDate': '2025-09-04T06:59Z',
#                             'entries': [{'alternateLabel': 'HOF',
#                                          'detail': 'Jul 31-Aug 6',
#                                          'endDate': '2025-08-07T06:59Z',
#                                          'label': 'Hall of Fame Weekend',
#                                          'startDate': '2025-07-31T07:00Z',
#                                          'value': '1'},
#                                         {'alternateLabel': 'Pre Wk 1',
#                                          'detail': 'Aug 7-13',
#                                          'endDate': '2025-08-14T06:59Z',
#                                          'label': 'Preseason Week 1',
#                                          'startDate': '2025-08-07T07:00Z',
#                                          'value': '2'},
#                                         {'alternateLabel': 'Pre Wk 2',
#                                          'detail': 'Aug 14-20',
#                                          'endDate': '2025-08-21T06:59Z',
#                                          'label': 'Preseason Week 2',
#                                          'startDate': '2025-08-14T07:00Z',
#                                          'value': '3'},
#                                         {'alternateLabel': 'Pre Wk 3',
#                                          'detail': 'Aug 21-Sep 3',
#                                          'endDate': '2025-09-04T06:59Z',
#                                          'label': 'Preseason Week 3',
#                                          'startDate': '2025-08-21T07:00Z',
#                                          'value': '4'}],
#                             'label': 'Preseason',
#                             'startDate': '2025-07-31T07:00Z',
#                             'value': '1'},
#                            {'endDate': '2026-01-07T07:59Z',
#                             'entries': [{'alternateLabel': 'Week 1',
#                                          'detail': 'Sep 4-9',
#                                          'endDate': '2025-09-10T06:59Z',
#                                          'label': 'Week 1',
#                                          'startDate': '2025-09-04T07:00Z',
#                                          'value': '1'},
#                                         {'alternateLabel': 'Week 2',
#                                          'detail': 'Sep 10-16',
#                                          'endDate': '2025-09-17T06:59Z',
#                                          'label': 'Week 2',
#                                          'startDate': '2025-09-10T07:00Z',
#                                          'value': '2'},
#                                         {'alternateLabel': 'Week 3',
#                                          'detail': 'Sep 17-23',
#                                          'endDate': '2025-09-24T06:59Z',
#                                          'label': 'Week 3',
#                                          'startDate': '2025-09-17T07:00Z',
#                                          'value': '3'},
#                                         {'alternateLabel': 'Week 4',
#                                          'detail': 'Sep 24-30',
#                                          'endDate': '2025-10-01T06:59Z',
#                                          'label': 'Week 4',
#                                          'startDate': '2025-09-24T07:00Z',
#                                          'value': '4'},
#                                         {'alternateLabel': 'Week 5',
#                                          'detail': 'Oct 1-7',
#                                          'endDate': '2025-10-08T06:59Z',
#                                          'label': 'Week 5',
#                                          'startDate': '2025-10-01T07:00Z',
#                                          'value': '5'},
#                                         {'alternateLabel': 'Week 6',
#                                          'detail': 'Oct 8-14',
#                                          'endDate': '2025-10-15T06:59Z',
#                                          'label': 'Week 6',
#                                          'startDate': '2025-10-08T07:00Z',
#                                          'value': '6'},
#                                         {'alternateLabel': 'Week 7',
#                                          'detail': 'Oct 15-21',
#                                          'endDate': '2025-10-22T06:59Z',
#                                          'label': 'Week 7',
#                                          'startDate': '2025-10-15T07:00Z',
#                                          'value': '7'},
#                                         {'alternateLabel': 'Week 8',
#                                          'detail': 'Oct 22-28',
#                                          'endDate': '2025-10-29T06:59Z',
#                                          'label': 'Week 8',
#                                          'startDate': '2025-10-22T07:00Z',
#                                          'value': '8'},
#                                         {'alternateLabel': 'Week 9',
#                                          'detail': 'Oct 29-Nov 4',
#                                          'endDate': '2025-11-05T07:59Z',
#                                          'label': 'Week 9',
#                                          'startDate': '2025-10-29T07:00Z',
#                                          'value': '9'},
#                                         {'alternateLabel': 'Week 10',
#                                          'detail': 'Nov 5-11',
#                                          'endDate': '2025-11-12T07:59Z',
#                                          'label': 'Week 10',
#                                          'startDate': '2025-11-05T08:00Z',
#                                          'value': '10'},
#                                         {'alternateLabel': 'Week 11',
#                                          'detail': 'Nov 12-18',
#                                          'endDate': '2025-11-19T07:59Z',
#                                          'label': 'Week 11',
#                                          'startDate': '2025-11-12T08:00Z',
#                                          'value': '11'},
#                                         {'alternateLabel': 'Week 12',
#                                          'detail': 'Nov 19-25',
#                                          'endDate': '2025-11-26T07:59Z',
#                                          'label': 'Week 12',
#                                          'startDate': '2025-11-19T08:00Z',
#                                          'value': '12'},
#                                         {'alternateLabel': 'Week 13',
#                                          'detail': 'Nov 26-Dec 2',
#                                          'endDate': '2025-12-03T07:59Z',
#                                          'label': 'Week 13',
#                                          'startDate': '2025-11-26T08:00Z',
#                                          'value': '13'},
#                                         {'alternateLabel': 'Week 14',
#                                          'detail': 'Dec 3-9',
#                                          'endDate': '2025-12-10T07:59Z',
#                                          'label': 'Week 14',
#                                          'startDate': '2025-12-03T08:00Z',
#                                          'value': '14'},
#                                         {'alternateLabel': 'Week 15',
#                                          'detail': 'Dec 10-16',
#                                          'endDate': '2025-12-17T07:59Z',
#                                          'label': 'Week 15',
#                                          'startDate': '2025-12-10T08:00Z',
#                                          'value': '15'},
#                                         {'alternateLabel': 'Week 16',
#                                          'detail': 'Dec 17-23',
#                                          'endDate': '2025-12-24T07:59Z',
#                                          'label': 'Week 16',
#                                          'startDate': '2025-12-17T08:00Z',
#                                          'value': '16'},
#                                         {'alternateLabel': 'Week 17',
#                                          'detail': 'Dec 24-30',
#                                          'endDate': '2025-12-31T07:59Z',
#                                          'label': 'Week 17',
#                                          'startDate': '2025-12-24T08:00Z',
#                                          'value': '17'},
#                                         {'alternateLabel': 'Week 18',
#                                          'detail': 'Dec 31-Jan 6',
#                                          'endDate': '2026-01-07T07:59Z',
#                                          'label': 'Week 18',
#                                          'startDate': '2025-12-31T08:00Z',
#                                          'value': '18'}],
#                             'label': 'Regular Season',
#                             'startDate': '2025-09-04T07:00Z',
#                             'value': '2'},
#                            {'endDate': '2026-02-12T07:59Z',
#                             'entries': [{'alternateLabel': 'Wild Card',
#                                          'detail': 'Jan 7-13',
#                                          'endDate': '2026-01-14T07:59Z',
#                                          'label': 'Wild Card',
#                                          'startDate': '2026-01-07T08:00Z',
#                                          'value': '1'},
#                                         {'alternateLabel': 'Div Rd',
#                                          'detail': 'Jan 14-20',
#                                          'endDate': '2026-01-21T07:59Z',
#                                          'label': 'Divisional Round',
#                                          'startDate': '2026-01-14T08:00Z',
#                                          'value': '2'},
#                                         {'alternateLabel': 'Conf Champ',
#                                          'detail': 'Jan 21-27',
#                                          'endDate': '2026-01-28T07:59Z',
#                                          'label': 'Conference Championship',
#                                          'startDate': '2026-01-21T08:00Z',
#                                          'value': '3'},
#                                         {'alternateLabel': 'Pro Bowl',
#                                          'detail': 'Jan 28-Feb 3',
#                                          'endDate': '2026-02-04T07:59Z',
#                                          'label': 'Pro Bowl',
#                                          'startDate': '2026-01-28T08:00Z',
#                                          'value': '4'},
#                                         {'alternateLabel': 'Super Bowl',
#                                          'detail': 'Feb 4-11',
#                                          'endDate': '2026-02-12T07:59Z',
#                                          'label': 'Super Bowl',
#                                          'startDate': '2026-02-04T08:00Z',
#                                          'value': '5'}],
#                             'label': 'Postseason',
#                             'startDate': '2026-01-07T08:00Z',
#                             'value': '3'},
#                            {'endDate': '2026-08-06T06:59Z',
#                             'entries': [{'alternateLabel': 'Week 1',
#                                          'detail': 'Feb 12-Jul 31',
#                                          'endDate': '2026-08-01T06:59Z',
#                                          'label': 'Week 1',
#                                          'startDate': '2026-02-12T08:00Z',
#                                          'value': '1'}],
#                             'label': 'Off Season',
#                             'startDate': '2026-02-12T08:00Z',
#                             'value': '4'}],
#               'calendarEndDate': '2026-02-12T07:59Z',
#               'calendarIsWhitelist': True,
#               'calendarStartDate': '2025-07-31T07:00Z',
#               'calendarType': 'list',
#               'id': '28',
#               'logos': [{'alt': '',
#                          'height': 500,
#                          'href': 'https://a.espncdn.com/i/teamlogos/leagues/500/nfl.png',
#                          'lastUpdated': '2018-06-05T12:07Z',
#                          'rel': ['full', 'default'],
#                          'width': 500},
#                         {'alt': '',
#                          'height': 500,
#                          'href': 'https://a.espncdn.com/i/teamlogos/leagues/500-dark/nfl.png',
#                          'lastUpdated': '2024-07-22T16:53Z',
#                          'rel': ['full', 'dark'],
#                          'width': 500}],
#               'name': 'National Football League',
#               'season': {'displayName': '2025',
#                          'endDate': '2026-02-12T07:59Z',
#                          'startDate': '2025-07-31T07:00Z',
#                          'type': {'abbreviation': 'post',
#                                   'id': '3',
#                                   'name': 'Postseason',
#                                   'type': 3},
#                          'year': 2025},
#               'slug': 'nfl',
#               'uid': 's:20~l:28'}],
#  'provider': {'displayName': 'Draft Kings',
#               'id': '100',
#               'logos': [{'href': 'https://a.espncdn.com/i/betting/Draftkings_Light.svg',
#                          'rel': ['light']},
#                         {'href': 'https://a.espncdn.com/i/betting/Draftkings_Dark.svg',
#                          'rel': ['dark']}],
#               'name': 'Draft Kings',
#               'priority': 1},
#  'season': {'type': 3, 'year': 2025},
#  'week': {'number': 4}}

# %%
import datetime

current_year = datetime.datetime.now().year
start_year = 2021

# %%
# I am pulling all regular season games from 2021-2026 (current season) bc that is the earliest season with 17 regular games. 
# I only want to see specific categories of data to simplify the df.

# %%
all_games = []

for year in range(start_year, current_year + 1):
    for week in range(1, 19):
        url = (
            "https://site.api.espn.com/apis/site/v2/"
            "sports/football/nfl/scoreboard"
            f"?seasontype=2&week={week}&year={year}"
        )

        response = requests.get(url)
        if response.status_code != 200:
            continue

        data = response.json()

        for event in data.get("events", []):
            if event["season"]["type"] != 2:
                continue

            competition = event["competitions"][0]
            competitors = competition["competitors"]

            home = next(t for t in competitors if t["homeAway"] == "home")
            away = next(t for t in competitors if t["homeAway"] == "away")

            all_games.append({
                "season": year,
                "week": week,
                "date": event["date"],
                "home_team": home["team"]["displayName"],
                "away_team": away["team"]["displayName"],
                "home_score": int(home.get("score", 0)),
                "away_score": int(away.get("score", 0)),
                "status": competition["status"]["type"]["name"]
            })

# %%
NFL_Regular_Season_Games_21to25_df = pd.DataFrame(all_games)
NFL_Regular_Season_Games_21to25_df.head()
# Out:
#    season  week               date             home_team  \
# 0    2021     1  2025-09-05T00:20Z   Philadelphia Eagles
# 1    2021     1  2025-09-06T00:00Z  Los Angeles Chargers
# 2    2021     1  2025-09-07T17:00Z       Atlanta Falcons
# 3    2021     1  2025-09-07T17:00Z      Cleveland Browns
# 4    2021     1  2025-09-07T17:00Z    Indianapolis Colts
#
#               away_team  home_score  away_score        status
# 0        Dallas Cowboys          24          20  STATUS_FINAL
# 1    Kansas City Chiefs          27          21  STATUS_FINAL
# 2  Tampa Bay Buccaneers          20          23  STATUS_FINAL
# 3    Cincinnati Bengals          16          17  STATUS_FINAL
# 4        Miami Dolphins          33           8  STATUS_FINAL

# %%
NFL_Regular_Season_Games_21to25_df = NFL_Regular_Season_Games_21to25_df[NFL_Regular_Season_Games_21to25_df["status"] == "STATUS_FINAL"]

# %%
# I only want final game scores, so I took out any games that were not final

# %%
NFL_Regular_Season_Games_21to25_df["status"].value_counts()
# Out:
# status
# STATUS_FINAL    1632
# Name: count, dtype: int64

# %%
# To double check my data, I checked the total number of games, correct if 272 (17 games x 32 teams / 2 teams) = 272 games per season

# %%
NFL_Regular_Season_Games_21to25_df["season"].value_counts().sort_index()
# Out:
# season
# 2021    272
# 2022    272
# 2023    272
# 2024    272
# 2025    272
# 2026    272
# Name: count, dtype: int64

# %%
NFL_Regular_Season_Games_21to25_df.sample(5)
# Out:
#       season  week               date             home_team  \
# 1175    2025     6  2025-10-12T20:05Z     Las Vegas Raiders
# 566     2023     2  2025-09-14T17:00Z    New Orleans Saints
# 1422    2026     4  2025-09-29T23:15Z        Miami Dolphins
# 852     2024     3  2025-09-21T17:00Z  New England Patriots
# 284     2022     1  2025-09-07T20:25Z     Green Bay Packers
#
#                 away_team  home_score  away_score        status
# 1175     Tennessee Titans          20          10  STATUS_FINAL
# 566   San Francisco 49ers          21          26  STATUS_FINAL
# 1422        New York Jets          27          21  STATUS_FINAL
# 852   Pittsburgh Steelers          14          21  STATUS_FINAL
# 284         Detroit Lions          27          13  STATUS_FINAL

# %%
# Going to eliminate "status" column because I know every game is final

# %%
NFL_Regular_Season_Games_21to25_df = NFL_Regular_Season_Games_21to25_df.drop(columns=["status"])

# %%
NFL_Regular_Season_Games_21to25_df.sample(5)
# Out:
#       season  week               date              home_team  \
# 884     2024     5  2025-10-05T17:00Z          New York Jets
# 142     2021    10  2025-11-09T18:00Z      Carolina Panthers
# 736     2023    13  2025-12-01T01:20Z  Washington Commanders
# 343     2022     5  2025-10-05T17:00Z       Baltimore Ravens
# 1347    2025    18  2026-01-04T18:00Z     Cincinnati Bengals
#
#                away_team  home_score  away_score
# 884       Dallas Cowboys          22          37
# 142   New Orleans Saints           7          17
# 736       Denver Broncos          26          27
# 343       Houston Texans          10          44
# 1347    Cleveland Browns          18          20

# %%
# Now I am going to change "date" to the format dd-mmm-yy so that it is easier to read

# %%
NFL_Regular_Season_Games_21to25_df["date"] = pd.to_datetime(
    NFL_Regular_Season_Games_21to25_df["date"],
    utc=True
)

# %%
NFL_Regular_Season_Games_21to25_df["date"] = (
    NFL_Regular_Season_Games_21to25_df["date"]
        .dt.strftime("%d-%b-%y")
        .str.upper()
)

# %%
NFL_Regular_Season_Games_21to25_df.sample(5)
# Out:
#       season  week       date              home_team          away_team  \
# 169     2021    12  23-NOV-25       Tennessee Titans   Seattle Seahawks
# 855     2024     3  21-SEP-25  Washington Commanders  Las Vegas Raiders
# 149     2021    11  14-NOV-25   New England Patriots      New York Jets
# 87      2021     6  12-OCT-25      Las Vegas Raiders   Tennessee Titans
# 1060    2024    17  28-DEC-25      Green Bay Packers   Baltimore Ravens
#
#       home_score  away_score
# 169           24          30
# 855           41          24
# 149           27          14
# 87            20          10
# 1060          24          41

# %%
# The data is now clean and in the format that I like, so I am going to convert it to a CSV

# %%
NFL_Regular_Season_Games_21to25_df.to_csv(
    "nfl_regular_season_games_2021_2025.csv",
    index=False
)

# %%
Clean_NFL_Score_Data_21to25_df = pd.read_csv("nfl_regular_season_games_2021_2025.csv")

# %%
Clean_NFL_Score_Data_21to25_df.head()
# Out:
#    season  week       date             home_team             away_team  \
# 0    2021     1  05-SEP-25   Philadelphia Eagles        Dallas Cowboys
# 1    2021     1  06-SEP-25  Los Angeles Chargers    Kansas City Chiefs
# 2    2021     1  07-SEP-25       Atlanta Falcons  Tampa Bay Buccaneers
# 3    2021     1  07-SEP-25      Cleveland Browns    Cincinnati Bengals
# 4    2021     1  07-SEP-25    Indianapolis Colts        Miami Dolphins
#
#    home_score  away_score
# 0          24          20
# 1          27          21
# 2          20          23
# 3          16          17
# 4          33           8

# %%
Clean_NFL_Score_Data_21to25_df["total_points"] = (
    Clean_NFL_Score_Data_21to25_df["home_score"]
    + Clean_NFL_Score_Data_21to25_df["away_score"]
)

# %%
Clean_NFL_Score_Data_21to25_df.head()
# Out:
#    season  week       date             home_team             away_team  \
# 0    2021     1  05-SEP-25   Philadelphia Eagles        Dallas Cowboys
# 1    2021     1  06-SEP-25  Los Angeles Chargers    Kansas City Chiefs
# 2    2021     1  07-SEP-25       Atlanta Falcons  Tampa Bay Buccaneers
# 3    2021     1  07-SEP-25      Cleveland Browns    Cincinnati Bengals
# 4    2021     1  07-SEP-25    Indianapolis Colts        Miami Dolphins
#
#    home_score  away_score  total_points
# 0          24          20            44
# 1          27          21            48
# 2          20          23            43
# 3          16          17            33
# 4          33           8            41

# %%
# I used Python to download NFL game data from ESPN’s API
# I selected regular season games from 2021 to 2025 and kept only the final game results
# I cleaned the data by removing unnecessary columns and I calculated the total number of points scored in each game
# After checking that the data looked correct, I saved the cleaned dataset as a CSV file so it can be used for analysis later
